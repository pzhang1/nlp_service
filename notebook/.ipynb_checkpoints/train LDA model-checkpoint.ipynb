# %% [markdown]
# ## Generate fake data

# %%
import random
from datetime import datetime, timedelta
from faker import Faker
import pandas as pd

fake = Faker()

# Generate a list of 100 company names
company_names = [fake.company() for _ in range(100)]

# Generate a list of 100 filed dates, spanning the past 5 years
start_date = datetime.today() - timedelta(days=1825) # 5 years ago
end_date = datetime.today()
filed_dates = [fake.date_between_dates(date_start=start_date, date_end=end_date) for _ in range(100)]

# Generate random text for each section
sections = ['Section1', 'Section1A', 'Section7']
section_texts = [[fake.paragraphs(nb=2), fake.paragraphs(nb=3), fake.paragraphs(nb=4)] for _ in range(100)]

# Create the DataFrame
df = pd.DataFrame({
    'companyName': company_names,
    'filedAt': filed_dates,
    'Section1': [section[0] for section in section_texts],
    'Section1A': [section[1] for section in section_texts],
    'Section7': [section[2] for section in section_texts]
})

# Print the first 5 rows of the DataFrame
print(df.head())
# Out:
#            companyName     filedAt  \
# 0        Ross-Gonzalez  2022-12-31
# 1       Huynh-Thompson  2019-06-20
# 2  Mclaughlin-Phillips  2019-03-19
# 3        Pope and Sons  2023-01-03
# 4          Parsons Ltd  2019-10-07
#
#                                             Section1  \
# 0  [Issue conference drop forget reduce affect fe...
# 1  [Fact during network always interview communit...
# 2  [Pressure situation land where Congress speak....
# 3  [Treat through million fine campaign same. Win...
# 4  [Letter lead reason challenge series amount ki...
#
#                                            Section1A  \
# 0  [Where prepare think control fly. Suddenly mus...
# 1  [Similar success where tough head improve tabl...
# 2  [Activity live condition popular court window ...
# 3  [Ask lose four national expert thank each. Aga...
# 4  [Clearly others over., Nation doctor according...
#
#                                             Section7
# 0  [Interview rise on something. Do sea remember ...
# 1  [Fast leg trade able behavior fight. Never air...
# 2  [Method officer rest especially. Investment ab...
# 3  [Fall attorney type begin audience leave teach...
# 4  [Give boy film. Particularly style key more hi...

# %%
import pandas as pd
import nltk
import gensim
from gensim.corpora import Dictionary
from gensim.models import LdaModel
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# %% [markdown]
# ### QUESTION 1: *What are the common topics mentioned in the SEC filings?

# %%
# Load the generated dataset (Replace with your dataset loading code if necessary)
# data = pd.read_csv('sample_data.csv')
data = df

# Download NLTK data
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /home/pengfei/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/pengfei/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /home/pengfei/nltk_data...
# True

# %%
# Prepare stop words
stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

def preprocess(text):
    tokens = [word for sent in sent_tokenize(text) for word in word_tokenize(sent)]
    tokens = [word.lower() for word in tokens if word.isalpha()]
    tokens = [word for word in tokens if word not in stop_words]
    tokens = [lemmatizer.lemmatize(word) for word in tokens]
    return tokens

# %%
# Prepare dataset for LDA analysis
all_texts = data["Section1"].tolist() + data["Section1A"].tolist() + data["Section7"].tolist()
all_texts = [" ".join(section) for section in all_texts]
processed_texts = [preprocess(text) for text in all_texts]

# %%
# Create Gensim dictionary, filter extremes, and convert to a bag-of-words corpus
dictionary = Dictionary(processed_texts)
dictionary.filter_extremes(no_below=10, no_above=0.5, keep_n=100000)
corpus = [dictionary.doc2bow(text) for text in processed_texts]

# %%
# Parameters for LDA
num_topics = 5
random_state = 100

# %%
# Train LDA model
lda = LdaModel(
    corpus,
    num_topics=num_topics,
    id2word=dictionary,
    random_state=random_state,
    update_every=1,
    passes=10,
    alpha='auto',
    per_word_topics=True
)

# %%
# Print topics
topics = lda.print_topics(num_words=5)

for topic in topics:
    print(topic)
# Out:
# (0, '0.009*"new" + 0.007*"establish" + 0.006*"sell" + 0.006*"decision" + 0.006*"free"')
# (1, '0.006*"start" + 0.005*"within" + 0.005*"lose" + 0.004*"kind" + 0.004*"grow"')
# (2, '0.006*"structure" + 0.006*"yes" + 0.005*"high" + 0.005*"industry" + 0.005*"available"')
# (3, '0.007*"whose" + 0.006*"return" + 0.006*"letter" + 0.006*"evidence" + 0.005*"science"')
# (4, '0.006*"mr" + 0.005*"professor" + 0.005*"value" + 0.004*"language" + 0.004*"accept"')

# %% [markdown]
# ### QUESTION 2: What are the emerging topics or financial themes over the last 5 years?

# %%
# Add a "year" column for grouping

data['filedAt'] = data['filedAt'].astype(str)
data['year'] = data['filedAt'].apply(lambda x: x[:4]).astype(int)

# %%
data.head()
# Out:
#            companyName     filedAt  \
# 0        Ross-Gonzalez  2022-12-31
# 1       Huynh-Thompson  2019-06-20
# 2  Mclaughlin-Phillips  2019-03-19
# 3        Pope and Sons  2023-01-03
# 4          Parsons Ltd  2019-10-07
#
#                                             Section1  \
# 0  [Issue conference drop forget reduce affect fe...
# 1  [Fact during network always interview communit...
# 2  [Pressure situation land where Congress speak....
# 3  [Treat through million fine campaign same. Win...
# 4  [Letter lead reason challenge series amount ki...
#
#                                            Section1A  \
# 0  [Where prepare think control fly. Suddenly mus...
# 1  [Similar success where tough head improve tabl...
# 2  [Activity live condition popular court window ...
# 3  [Ask lose four national expert thank each. Aga...
# 4  [Clearly others over., Nation doctor according...
#
#                                             Section7  year
# 0  [Interview rise on something. Do sea remember ...  2022
# 1  [Fast leg trade able behavior fight. Never air...  2019
# 2  [Method officer rest especially. Investment ab...  2019
# 3  [Fall attorney type begin audience leave teach...  2023
# 4  [Give boy film. Particularly style key more hi...  2019

# %%
# LDA analysis for a given year
def analyze_year(year, num_topics=5, random_state=100):
    year_data = data[data['year'] == year]
#     print(len(year_data))
    all_texts = year_data["Section1"].tolist() + year_data["Section1A"].tolist() + year_data["Section7"].tolist()
    all_texts = [" ".join(section) for section in all_texts]
    processed_texts = [preprocess(text) for text in all_texts]
#     print(processed_texts)
    dictionary = Dictionary(processed_texts)
#     dictionary.filter_extremes()
    corpus = [dictionary.doc2bow(text) for text in processed_texts]
#     print(corpus)
    lda = LdaModel(
        corpus,
        num_topics=num_topics,
        id2word=dictionary,
        random_state=random_state,
        update_every=1,
        passes=10,
        alpha='auto',
        per_word_topics=True
    )

    topics = lda.print_topics(num_words=5)
    return topics

# %%
data[data['year'] == 2018]
# Out:
#                  companyName     filedAt  \
# 6                Chapman PLC  2018-10-14
# 15               Allison LLC  2018-10-23
# 26            Moore-Cisneros  2018-11-20
# 41        Gonzales-Carpenter  2018-10-20
# 43           Dominguez Group  2018-11-30
# 91  Webb, Kaufman and Wagner  2018-09-30
#
#                                              Section1  \
# 6   [Own face but move result general mean., Perso...
# 15  [Including agent Congress strong large. Large ...
# 26  [Then want thing important six require signifi...
# 41  [Wish draw deep exactly gas environmental. Sou...
# 43  [Several southern buy example mean four. Groun...
# 91  [True our nation try describe sister. Sense me...
#
#                                             Section1A  \
# 6   [Rather food deal difference explain sing brea...
# 15  [It memory compare health. Eat bill through im...
# 26  [Make per nearly increase. Beat tell by daught...
# 41  [Break even even onto side. World of often sho...
# 43  [Then garden sometimes series across center po...
# 91  [Help likely bag necessary. Thus table reduce ...
#
#                                              Section7  year
# 6   [Often body method whether democratic little r...  2018
# 15  [Something four exist red. Sign senior page. P...  2018
# 26  [Health on clear. Year Congress actually avail...  2018
# 41  [Law according culture identify same environme...  2018
# 43  [Success whether affect. Mouth able tree debat...  2018
# 91  [Spend up choice. Force some message away disc...  2018

# %%
unique_years
# Out:
# [2018, 2019, 2020, 2021, 2022, 2023]

# %%
# Group documents by year and analyze each year
unique_years = sorted(data['year'].unique())

for year in unique_years:
    print(f"Topics for year {year}:")
    topics = analyze_year(year, num_topics=5, random_state=100)
    for topic in topics:
        print(topic)
    print("\n")
# Out:
# Topics for year 2018:
# (0, '0.016*"health" + 0.008*"table" + 0.008*"task" + 0.008*"choice" + 0.008*"upon"')
# (1, '0.011*"run" + 0.008*"main" + 0.008*"whether" + 0.008*"way" + 0.008*"professional"')
# (2, '0.013*"history" + 0.013*"market" + 0.013*"congress" + 0.013*"large" + 0.007*"check"')
# (3, '0.010*"million" + 0.010*"building" + 0.010*"point" + 0.010*"single" + 0.010*"big"')
# (4, '0.014*"later" + 0.014*"reduce" + 0.009*"space" + 0.009*"cold" + 0.009*"try"')
#
#
# Topics for year 2019:
# (0, '0.008*"high" + 0.008*"try" + 0.008*"scientist" + 0.008*"drive" + 0.008*"site"')
# (1, '0.008*"item" + 0.008*"capital" + 0.007*"central" + 0.006*"significant" + 0.006*"network"')
# (2, '0.007*"tough" + 0.006*"book" + 0.006*"view" + 0.006*"indicate" + 0.005*"think"')
# (3, '0.006*"exactly" + 0.006*"present" + 0.006*"anything" + 0.006*"week" + 0.006*"letter"')
# (4, '0.007*"language" + 0.007*"ten" + 0.006*"time" + 0.006*"western" + 0.006*"writer"')
#
#
# Topics for year 2020:
# (0, '0.009*"kitchen" + 0.009*"within" + 0.009*"heavy" + 0.007*"least" + 0.007*"consider"')
# (1, '0.007*"rule" + 0.007*"special" + 0.006*"growth" + 0.006*"mr" + 0.006*"staff"')
# (2, '0.006*"turn" + 0.006*"century" + 0.006*"recognize" + 0.006*"relate" + 0.006*"modern"')
# (3, '0.008*"detail" + 0.006*"nature" + 0.006*"throughout" + 0.006*"board" + 0.006*"case"')
# (4, '0.009*"least" + 0.007*"person" + 0.007*"pull" + 0.007*"seven" + 0.007*"consumer"')
#
#
# Topics for year 2021:
# (0, '0.009*"expect" + 0.006*"modern" + 0.006*"tend" + 0.006*"road" + 0.005*"direction"')
# (1, '0.007*"yes" + 0.007*"science" + 0.005*"travel" + 0.005*"water" + 0.005*"various"')
# (2, '0.008*"high" + 0.007*"floor" + 0.005*"five" + 0.005*"day" + 0.005*"situation"')
# (3, '0.007*"tree" + 0.006*"size" + 0.006*"bring" + 0.005*"start" + 0.005*"picture"')
# (4, '0.007*"around" + 0.006*"turn" + 0.006*"ever" + 0.006*"smile" + 0.005*"finish"')
#
#
# Topics for year 2022:
# (0, '0.006*"grow" + 0.006*"enough" + 0.006*"pas" + 0.006*"control" + 0.005*"least"')
# (1, '0.008*"carry" + 0.007*"director" + 0.007*"experience" + 0.005*"north" + 0.005*"brother"')
# (2, '0.006*"source" + 0.006*"professor" + 0.006*"address" + 0.006*"congress" + 0.005*"believe"')
# (3, '0.006*"benefit" + 0.006*"important" + 0.005*"eye" + 0.005*"lose" + 0.005*"individual"')
# (4, '0.006*"seat" + 0.006*"sport" + 0.006*"suggest" + 0.006*"education" + 0.006*"decade"')
#
#
# Topics for year 2023:
# (0, '0.009*"painting" + 0.009*"bit" + 0.009*"foot" + 0.009*"international" + 0.009*"free"')
# (1, '0.008*"skin" + 0.006*"able" + 0.006*"along" + 0.006*"lose" + 0.006*"national"')
# (2, '0.013*"south" + 0.009*"future" + 0.009*"design" + 0.009*"cell" + 0.009*"decade"')
# (3, '0.011*"run" + 0.009*"alone" + 0.006*"boy" + 0.006*"house" + 0.006*"window"')
# (4, '0.008*"artist" + 0.008*"war" + 0.008*"approach" + 0.008*"enter" + 0.008*"section"')

# %% [markdown]
# ### QUESTION 3:  **What are the declining themes?*

# %%
def analyze_year(year, num_topics=5, random_state=100):
    year_data = data[data["year"] == year]
    all_texts = year_data["Section1"].tolist() + year_data["Section1A"].tolist() + year_data["Section7"].tolist()
    all_texts = [" ".join(section) for section in all_texts]
    processed_texts = [preprocess(text) for text in all_texts]
#     print(processed_texts)
    dictionary = Dictionary(processed_texts)
#     dictionary.filter_extremes(no_below=10, no_above=0.5, keep_n=100000)
    corpus = [dictionary.doc2bow(text) for text in processed_texts]

    lda = LdaModel(
        corpus,
        num_topics=num_topics,
        id2word=dictionary,
        random_state=random_state,
        update_every=1,
        passes=10,
        alpha="auto",
        per_word_topics=True,
    )

    topics = lda.print_topics(num_words=5)
    return topics, processed_texts

# %%
from collections import defaultdict

# %%
def get_word_frequencies(words, processed_texts):
    word_frequencies = defaultdict(int)
    for word in words:
        for text in processed_texts:
            word_frequencies[word] += text.count(word)
    return word_frequencies

unique_years = sorted(data["year"].unique())
all_topics = []
all_processed_texts = []

# %%
for year in unique_years:
    topics, processed_texts = analyze_year(year, num_topics=5, random_state=100)
    all_topics.extend(topics)
    all_processed_texts.extend(processed_texts)

# %%
all_processed_texts
# Out:
# [['face',
#   'move',
#   'result',
#   'general',
#   'mean',
#   'person',
#   'hundred',
#   'study',
#   'later',
#   'cold',
#   'local',
#   'trouble',
#   'stand',
#   'space',
#   'set',
#   'clear',
#   'reflect',
#   'certain',
#   'try',
#   'player',
#   'agreement'],
#  ['including',
#   'agent',
#   'congress',
#   'strong',
#   'large',
#   'large',
#   'month',
#   'wife',
#   'fear',
#   'know',
#   'market',
#   'upon',
#   'around',
#   'politics',
#   'boy'],
#  ['want',
#   'thing',
#   'important',
#   'six',
#   'require',
#   'significant',
#   'must',
#   'building',
#   'feeling',
#   'loss',
#   'model',
#   'purpose',
#   'professor',
#   'indeed',
#   'early',
#   'color',
#   'parent',
#   'single',
#   'officer',
#   'read',
#   'like',
#   'point',
#   'protect',
#   'worker',
#   'care',
#   'true',
#   'whether'],
#  ['wish',
#   'draw',
#   'deep',
#   'exactly',
#   'gas',
#   'environmental',
#   'southern',
#   'appear',
#   'million',
#   'however',
#   'watch',
#   'size',
#   'prepare',
#   'official',
#   'new',
#   'kitchen',
#   'group',
#   'million',
#   'big',
#   'tax',
#   'avoid'],
#  ['several',
#   'southern',
#   'buy',
#   'example',
#   'mean',
#   'four',
#   'ground',
#   'open',
#   'population',
#   'new',
#   'value',
#   'magazine',
#   'later',
#   'reduce',
#   'meet',
#   'front',
#   'task',
#   'growth',
#   'plan',
#   'instead'],
#  ['true',
#   'nation',
#   'try',
#   'describe',
#   'sister',
#   'sense',
#   'medical',
#   'role',
#   'idea',
#   'child',
#   'current',
#   'thing',
#   'possible',
#   'fish',
#   'hospital',
#   'local',
#   'together',
#   'social',
#   'black',
#   'opportunity',
#   'note',
#   'day',
#   'fly',
#   'school',
#   'south',
#   'area',
#   'every',
#   'example'],
#  ['rather',
#   'food',
#   'deal',
#   'difference',
#   'explain',
#   'sing',
#   'break',
#   'hit',
#   'president',
#   'reveal',
#   'feel',
#   'third',
#   'another',
#   'billion',
#   'type',
#   'bag',
#   'recent',
#   'fire',
#   'sell',
#   'design',
#   'citizen',
#   'cover',
#   'democrat',
#   'war',
#   'smile',
#   'individual',
#   'let',
#   'staff',
#   'enjoy',
#   'employee',
#   'happy',
#   'often',
#   'power'],
#  ['memory',
#   'compare',
#   'health',
#   'eat',
#   'bill',
#   'improve',
#   'natural',
#   'across',
#   'task',
#   'effect',
#   'table',
#   'rule',
#   'voice',
#   'employee',
#   'serve',
#   'around',
#   'bank',
#   'particularly',
#   'system',
#   'choice',
#   'health',
#   'upon',
#   'yard',
#   'light',
#   'law'],
#  ['make',
#   'per',
#   'nearly',
#   'increase',
#   'beat',
#   'tell',
#   'daughter',
#   'top',
#   'throw',
#   'evening',
#   'across',
#   'water',
#   'sport',
#   'since',
#   'reduce',
#   'old',
#   'natural',
#   'try',
#   'great',
#   'foreign',
#   'current',
#   'along',
#   'remain',
#   'career',
#   'many',
#   'today',
#   'support',
#   'ten',
#   'interesting',
#   'student',
#   'poor',
#   'support',
#   'industry',
#   'really',
#   'expect',
#   'left',
#   'remember',
#   'response',
#   'according',
#   'late',
#   'rise',
#   'receive',
#   'arrive'],
#  ['break',
#   'even',
#   'even',
#   'onto',
#   'side',
#   'world',
#   'often',
#   'run',
#   'next',
#   'political',
#   'mind',
#   'establish',
#   'truth',
#   'win',
#   'professional',
#   'claim',
#   'main',
#   'summer',
#   'month',
#   'long',
#   'serious',
#   'lawyer',
#   'sort',
#   'brother',
#   'new',
#   'country',
#   'dream',
#   'though',
#   'task',
#   'hot',
#   'physical'],
#  ['garden',
#   'sometimes',
#   'series',
#   'across',
#   'center',
#   'popular',
#   'personal',
#   'office',
#   'work',
#   'decision',
#   'line',
#   'simple',
#   'bag',
#   'democratic',
#   'treatment',
#   'rock',
#   'staff',
#   'lead',
#   'effort',
#   'low',
#   'red',
#   'since',
#   'individual',
#   'customer',
#   'rule',
#   'music',
#   'return',
#   'see',
#   'professional',
#   'continue',
#   'house',
#   'billion',
#   'quality',
#   'bank',
#   'food',
#   'manager',
#   'others',
#   'test',
#   'baby',
#   'allow',
#   'bring',
#   'talk',
#   'administration',
#   'single',
#   'big',
#   'miss',
#   'painting',
#   'end',
#   'onto'],
#  ['help',
#   'likely',
#   'bag',
#   'necessary',
#   'thus',
#   'table',
#   'reduce',
#   'blue',
#   'defense',
#   'yeah',
#   'experience',
#   'none',
#   'seem',
#   'others',
#   'respond',
#   'exactly',
#   'daughter',
#   'allow',
#   'note',
#   'space',
#   'summer',
#   'anyone',
#   'address',
#   'training',
#   'beyond',
#   'adult',
#   'tell',
#   'later',
#   'cold'],
#  ['often',
#   'body',
#   'method',
#   'whether',
#   'democratic',
#   'little',
#   'run',
#   'site',
#   'purpose',
#   'sell',
#   'hard',
#   'assume',
#   'guy',
#   'sign',
#   'involve',
#   'reduce',
#   'whatever',
#   'whole',
#   'south',
#   'push',
#   'daughter',
#   'happen',
#   'writer',
#   'perform',
#   'picture',
#   'though',
#   'four',
#   'ten',
#   'speak',
#   'positive',
#   'office',
#   'rather',
#   'professor',
#   'seem',
#   'character',
#   'dream',
#   'doctor',
#   'way',
#   'movement',
#   'far',
#   'draw',
#   'provide',
#   'treatment',
#   'practice'],
#  ['something',
#   'four',
#   'exist',
#   'red',
#   'sign',
#   'senior',
#   'page',
#   'picture',
#   'money',
#   'item',
#   'building',
#   'meeting',
#   'feeling',
#   'environment',
#   'support',
#   'hair',
#   'hotel',
#   'reveal',
#   'else',
#   'begin',
#   'phone',
#   'middle',
#   'former',
#   'city',
#   'rate',
#   'become',
#   'simple',
#   'social',
#   'easy',
#   'point',
#   'check',
#   'gas',
#   'lose',
#   'fish',
#   'floor',
#   'industry',
#   'pas',
#   'capital',
#   'feel',
#   'firm',
#   'experience',
#   'chair'],
#  ['health',
#   'clear',
#   'year',
#   'congress',
#   'actually',
#   'available',
#   'according',
#   'sure',
#   'return',
#   'thing',
#   'attack',
#   'mention',
#   'risk',
#   'child',
#   'rest',
#   'history',
#   'pretty',
#   'meet',
#   'government',
#   'place',
#   'market',
#   'win',
#   'national',
#   'military',
#   'unit',
#   'hot',
#   'reality',
#   'approach',
#   'force',
#   'check',
#   'certain',
#   'goal',
#   'door',
#   'push',
#   'condition',
#   'history',
#   'central',
#   'partner',
#   'speak',
#   'tough',
#   'ready',
#   'respond',
#   'teacher',
#   'current',
#   'early',
#   'never',
#   'player',
#   'bill',
#   'nation',
#   'accept',
#   'minute',
#   'quickly',
#   'key',
#   'carry',
#   'second',
#   'institution',
#   'produce',
#   'oil',
#   'probably',
#   'leave',
#   'kitchen'],
#  ['law',
#   'according',
#   'culture',
#   'identify',
#   'environment',
#   'form',
#   'result',
#   'executive',
#   'fact',
#   'nearly',
#   'foreign',
#   'scene',
#   'catch',
#   'ask',
#   'discover',
#   'away',
#   'economy',
#   'wait',
#   'evidence',
#   'use',
#   'environment',
#   'fight',
#   'success',
#   'actually',
#   'system',
#   'congress',
#   'left',
#   'reflect',
#   'sign',
#   'professional',
#   'run',
#   'fine',
#   'close',
#   'energy',
#   'participant',
#   'actually',
#   'go',
#   'design',
#   'summer'],
#  ['success',
#   'whether',
#   'affect',
#   'mouth',
#   'able',
#   'tree',
#   'debate',
#   'last',
#   'front',
#   'interest',
#   'road',
#   'member',
#   'compare',
#   'fish',
#   'knowledge',
#   'security',
#   'time',
#   'big',
#   'appear',
#   'detail',
#   'city',
#   'simply',
#   'figure',
#   'put',
#   'participant',
#   'prevent',
#   'concern',
#   'cost',
#   'shoulder',
#   'blue',
#   'way',
#   'represent',
#   'main',
#   'defense',
#   'shake',
#   'card',
#   'year',
#   'support',
#   'man',
#   'campaign',
#   'threat',
#   'political',
#   'manage'],
#  ['spend',
#   'choice',
#   'force',
#   'message',
#   'away',
#   'discussion',
#   'reality',
#   'order',
#   'upon',
#   'style',
#   'seat',
#   'lay',
#   'space',
#   'force',
#   'stuff',
#   'theory',
#   'clearly',
#   'else',
#   'ten',
#   'near',
#   'game',
#   'group',
#   'institution',
#   'administration',
#   'drug',
#   'admit',
#   'method',
#   'charge',
#   'foot',
#   'able',
#   'early',
#   'today',
#   'carry',
#   'someone',
#   'sort',
#   'adult',
#   'left',
#   'inside',
#   'audience'],
#  ['fact',
#   'network',
#   'always',
#   'interview',
#   'community',
#   'table',
#   'region',
#   'future',
#   'prevent',
#   'money',
#   'born',
#   'record',
#   'book',
#   'nearly',
#   'good',
#   'certain',
#   'something',
#   'vote',
#   'however',
#   'program',
#   'book',
#   'effort',
#   'others',
#   'change',
#   'film',
#   'republican',
#   'leader',
#   'table',
#   'rate',
#   'animal',
#   'film',
#   'view',
#   'operation',
#   'indicate',
#   'indicate',
#   'think',
#   'draw',
#   'answer',
#   'alone',
#   'economy'],
#  ['pressure',
#   'situation',
#   'land',
#   'congress',
#   'speak',
#   'le',
#   'kind',
#   'attack',
#   'plan',
#   'thank',
#   'attorney',
#   'read',
#   'offer',
#   'wrong',
#   'everything',
#   'ago',
#   'third',
#   'social',
#   'fear',
#   'believe',
#   'event',
#   'author',
#   'election',
#   'surface'],
#  ['letter',
#   'lead',
#   'reason',
#   'challenge',
#   'series',
#   'amount',
#   'kind',
#   'might',
#   'within',
#   'network',
#   'rest',
#   'research',
#   'condition',
#   'executive',
#   'drug'],
#  ['thus',
#   'director',
#   'ready',
#   'ground',
#   'despite',
#   'surface',
#   'message',
#   'seem',
#   'treat',
#   'edge',
#   'day',
#   'president',
#   'industry',
#   'realize'],
#  ['knowledge',
#   'artist',
#   'example',
#   'gas',
#   'never',
#   'wrong',
#   'within',
#   'threat',
#   'item',
#   'card',
#   'argue',
#   'reach',
#   'mention',
#   'indeed',
#   'wish',
#   'forget',
#   'money',
#   'le'],
#  ['performance',
#   'fall',
#   'energy',
#   'best',
#   'give',
#   'mention',
#   'western',
#   'letter',
#   'take',
#   'compare',
#   'large',
#   'born',
#   'scientist',
#   'away',
#   'option',
#   'party'],
#  ['thank',
#   'job',
#   'brother',
#   'eight',
#   'green',
#   'hand',
#   'dog',
#   'walk',
#   'address',
#   'everything',
#   'everybody',
#   'develop',
#   'half',
#   'language',
#   'join',
#   'significant',
#   'concern',
#   'cultural',
#   'minute',
#   'discussion',
#   'white',
#   'benefit',
#   'team',
#   'continue',
#   'service'],
#  ['drive',
#   'main',
#   'group',
#   'indeed',
#   'raise',
#   'style',
#   'national',
#   'central',
#   'painting',
#   'nearly',
#   'space',
#   'tax',
#   'perhaps',
#   'forget',
#   'scientist',
#   'prepare',
#   'real',
#   'begin',
#   'reason',
#   'exactly',
#   'coach',
#   'unit',
#   'true',
#   'either',
#   'area',
#   'majority',
#   'author',
#   'return',
#   'party'],
#  ['always',
#   'recent',
#   'kitchen',
#   'reason',
#   'discus',
#   'security',
#   'high',
#   'value',
#   'try',
#   'various',
#   'task',
#   'offer',
#   'within',
#   'beautiful',
#   'pay',
#   'provide',
#   'heavy',
#   'detail',
#   'require',
#   'letter',
#   'mother',
#   'hard',
#   'recognize',
#   'computer',
#   'see'],
#  ['minute',
#   'director',
#   'decision',
#   'actually',
#   'white',
#   'husband',
#   'really',
#   'yeah',
#   'east',
#   'type',
#   'recognize',
#   'especially',
#   'thousand',
#   'building',
#   'try',
#   'upon',
#   'impact',
#   'particular',
#   'several',
#   'smile',
#   'positive',
#   'pull',
#   'blue',
#   'practice',
#   'skin',
#   'card',
#   'impact',
#   'product',
#   'next',
#   'teacher'],
#  ['heart',
#   'pm',
#   'song',
#   'effect',
#   'store',
#   'answer',
#   'million',
#   'reach',
#   'care',
#   'put',
#   'question',
#   'picture',
#   'receive',
#   'suddenly',
#   'statement',
#   'leave',
#   'opportunity',
#   'attention',
#   'current',
#   'board',
#   'adult',
#   'particularly',
#   'amount'],
#  ['able',
#   'would',
#   'whole',
#   'perhaps',
#   'western',
#   'language',
#   'grow',
#   'lead',
#   'investment',
#   'point',
#   'white',
#   'language',
#   'face',
#   'sure',
#   'time',
#   'truth',
#   'provide',
#   'make',
#   'politics',
#   'across',
#   'brother',
#   'detail',
#   'book',
#   'successful',
#   'network',
#   'top',
#   'everybody',
#   'similar',
#   'next',
#   'west',
#   'ever',
#   'section',
#   'minute',
#   'glass',
#   'chair',
#   'either',
#   'subject',
#   'gun'],
#  ['fly',
#   'military',
#   'benefit',
#   'ground',
#   'imagine',
#   'step',
#   'collection',
#   'mouth',
#   'kind',
#   'practice',
#   'clear',
#   'son',
#   'success',
#   'building',
#   'ten',
#   'management',
#   'term',
#   'friend',
#   'event',
#   'mission',
#   'say',
#   'ten',
#   'report',
#   'authority',
#   'real',
#   'list',
#   'control',
#   'green'],
#  ['pull',
#   'order',
#   'however',
#   'half',
#   'support',
#   'forget',
#   'agreement',
#   'somebody',
#   'central',
#   'show',
#   'capital',
#   'may',
#   'nation',
#   'capital',
#   'entire',
#   'local',
#   'public',
#   'development',
#   'learn',
#   'mother',
#   'artist'],
#  ['consumer',
#   'along',
#   'right',
#   'student',
#   'baby',
#   'husband',
#   'newspaper',
#   'argue',
#   'front',
#   'activity',
#   'garden',
#   'others',
#   'everybody',
#   'tree',
#   'tonight',
#   'several',
#   'short',
#   'network',
#   'beat',
#   'significant',
#   'put',
#   'weight',
#   'fund',
#   'throw',
#   'happy',
#   'quality',
#   'heavy',
#   'five',
#   'five',
#   'light',
#   'rise',
#   'risk',
#   'sea',
#   'decision',
#   'business',
#   'floor'],
#  ['particular',
#   'among',
#   'check',
#   'open',
#   'require',
#   'need',
#   'wonder',
#   'paper',
#   'allow',
#   'risk',
#   'hundred',
#   'exactly',
#   'market',
#   'drug',
#   'response',
#   'ten',
#   'enter',
#   'assume',
#   'onto',
#   'increase',
#   'level',
#   'clearly',
#   'thought',
#   'prevent',
#   'share',
#   'hold',
#   'project',
#   'stuff',
#   'born',
#   'foot',
#   'work',
#   'education',
#   'data'],
#  ['tough',
#   'ok',
#   'movement',
#   'similar',
#   'teach',
#   'least',
#   'head',
#   'authority',
#   'fill',
#   'power',
#   'reduce',
#   'wide',
#   'change',
#   'help',
#   'treat',
#   'evening',
#   'full',
#   'say',
#   'list',
#   'word',
#   'population'],
#  ['around',
#   'president',
#   'agent',
#   'go',
#   'item',
#   'kitchen',
#   'computer',
#   'position',
#   'physical',
#   'occur',
#   'follow',
#   'central',
#   'head',
#   'vote',
#   'range',
#   'administration',
#   'pm',
#   'free',
#   'morning',
#   'report',
#   'sit',
#   'new',
#   'phone',
#   'area',
#   'record',
#   'likely',
#   'heart'],
#  ['standard',
#   'man',
#   'college',
#   'modern',
#   'every',
#   'teacher',
#   'brother',
#   'identify',
#   'method',
#   'night',
#   'degree',
#   'husband',
#   'present',
#   'serve',
#   'foreign',
#   'pretty',
#   'camera',
#   'majority',
#   'floor',
#   'majority',
#   'behavior',
#   'teach',
#   'partner',
#   'history',
#   'letter',
#   'everyone',
#   'best',
#   'item',
#   'pay',
#   'effect',
#   'interest',
#   'occur'],
#  ['similar',
#   'success',
#   'tough',
#   'head',
#   'improve',
#   'table',
#   'return',
#   'picture',
#   'throughout',
#   'road',
#   'present',
#   'tend',
#   'risk',
#   'available',
#   'build',
#   'attention',
#   'back',
#   'responsibility',
#   'turn',
#   'find',
#   'tough',
#   'although',
#   'along',
#   'would',
#   'research',
#   'front',
#   'professional',
#   'factor',
#   'prevent',
#   'front',
#   'control',
#   'similar',
#   'treatment',
#   'beautiful',
#   'pressure',
#   'appear',
#   'sign',
#   'defense',
#   'contain',
#   'truth',
#   'reach'],
#  ['activity',
#   'live',
#   'condition',
#   'popular',
#   'court',
#   'window',
#   'skin',
#   'east',
#   'magazine',
#   'common',
#   'evidence',
#   'guess',
#   'rock',
#   'place',
#   'entire',
#   'manage',
#   'specific',
#   'language',
#   'contain',
#   'color',
#   'network',
#   'doctor',
#   'without',
#   'continue',
#   'radio',
#   'general',
#   'level',
#   'world',
#   'hit',
#   'money',
#   'drop',
#   'true',
#   'treatment',
#   'poor',
#   'take',
#   'environmental'],
#  ['clearly',
#   'others',
#   'nation',
#   'doctor',
#   'according',
#   'degree',
#   'check',
#   'born',
#   'significant',
#   'become',
#   'manage',
#   'cover',
#   'final',
#   'remember',
#   'position',
#   'wife',
#   'manager',
#   'treat',
#   'listen',
#   'get',
#   'police',
#   'community',
#   'win',
#   'production',
#   'study'],
#  ['fact',
#   'ten',
#   'table',
#   'successful',
#   'late',
#   'approach',
#   'oil',
#   'tax',
#   'election',
#   'behavior',
#   'meeting',
#   'history',
#   'behind',
#   'upon',
#   'one',
#   'really',
#   'often',
#   'wife',
#   'yes',
#   'per',
#   'time',
#   'might',
#   'smile',
#   'record',
#   'area',
#   'oil',
#   'attack',
#   'environmental',
#   'wrong',
#   'surface',
#   'control',
#   'become',
#   'surface',
#   'feel',
#   'quickly',
#   'house',
#   'film',
#   'common'],
#  ['hour',
#   'south',
#   'range',
#   'central',
#   'hit',
#   'foreign',
#   'usually',
#   'among',
#   'run',
#   'much',
#   'western',
#   'picture',
#   'hard',
#   'magazine',
#   'play',
#   'pretty',
#   'simple',
#   'final',
#   'laugh',
#   'language',
#   'movement',
#   'design',
#   'writer',
#   'recently',
#   'positive',
#   'table',
#   'writer',
#   'view',
#   'movie',
#   'ability',
#   'claim',
#   'officer',
#   'specific',
#   'trade',
#   'staff',
#   'record',
#   'report',
#   'compare',
#   'dinner',
#   'crime',
#   'speech',
#   'force',
#   'see',
#   'suggest',
#   'green',
#   'tell',
#   'education'],
#  ['truth',
#   'arrive',
#   'church',
#   'enjoy',
#   'push',
#   'base',
#   'year',
#   'position',
#   'job',
#   'deep',
#   'final',
#   'better',
#   'smile',
#   'participant',
#   'customer',
#   'general',
#   'within',
#   'realize',
#   'various',
#   'pressure',
#   'others',
#   'fear',
#   'develop',
#   'successful',
#   'central',
#   'environmental',
#   'third',
#   'western',
#   'simple',
#   'ok',
#   'professional',
#   'study',
#   'whatever',
#   'set',
#   'model',
#   'position',
#   'ball',
#   'clearly',
#   'cultural',
#   'learn',
#   'age',
#   'teacher',
#   'president',
#   'wait',
#   'language',
#   'agent',
#   'tonight',
#   'child'],
#  ['assume',
#   'method',
#   'lose',
#   'personal',
#   'skin',
#   'whole',
#   'purpose',
#   'read',
#   'simple',
#   'thus',
#   'table',
#   'economy',
#   'one',
#   'among',
#   'speech',
#   'name',
#   'past',
#   'throw',
#   'including',
#   'find',
#   'yes',
#   'fall',
#   'peace',
#   'knowledge',
#   'sure',
#   'report',
#   'represent',
#   'today',
#   'seven',
#   'suggest',
#   'shoulder',
#   'past'],
#  ['represent',
#   'direction',
#   'later',
#   'east',
#   'early',
#   'production',
#   'affect',
#   'place',
#   'still',
#   'year',
#   'sense',
#   'require',
#   'example',
#   'shoulder',
#   'exactly',
#   'south',
#   'course',
#   'appear',
#   'memory',
#   'drug',
#   'everything',
#   'military',
#   'idea',
#   'discus',
#   'film',
#   'become',
#   'without',
#   'southern',
#   'cause',
#   'never'],
#  ['range',
#   'join',
#   'card',
#   'cold',
#   'rule',
#   'hotel',
#   'perhaps',
#   'difficult',
#   'weight',
#   'western',
#   'evidence',
#   'agreement',
#   'maintain',
#   'walk',
#   'statement',
#   'institution',
#   'read',
#   'year',
#   'case',
#   'first',
#   'grow',
#   'ball',
#   'partner',
#   'understand',
#   'reason',
#   'tend',
#   'lot',
#   'strategy',
#   'boy',
#   'region',
#   'piece',
#   'back',
#   'truth',
#   'activity',
#   'order',
#   'though',
#   'statement',
#   'lay',
#   'item',
#   'national',
#   'southern',
#   'imagine'],
#  ['close',
#   'evening',
#   'live',
#   'pattern',
#   'boy',
#   'left',
#   'set',
#   'rise',
#   'wonder',
#   'town',
#   'fight',
#   'current',
#   'citizen',
#   'hot',
#   'call',
#   'use',
#   'trade',
#   'yeah',
#   'realize',
#   'follow',
#   'travel',
#   'three',
#   'capital',
#   'skill',
#   'amount',
#   'direction',
#   'degree',
#   'room',
#   'apply'],
#  ['north',
#   'response',
#   'politics',
#   'institution',
#   'weight',
#   'politics',
#   'deal',
#   'campaign',
#   'computer',
#   'season',
#   'church',
#   'candidate',
#   'worry',
#   'factor',
#   'easy',
#   'fact',
#   'wife',
#   'big',
#   'manager',
#   'practice',
#   'sure',
#   'relationship',
#   'later',
#   'nature',
#   'story',
#   'pay',
#   'research',
#   'ago',
#   'throughout',
#   'wear',
#   'sound',
#   'age',
#   'hundred',
#   'develop',
#   'exactly',
#   'black',
#   'customer',
#   'artist',
#   'page'],
#  ['major',
#   'animal',
#   'area',
#   'high',
#   'call',
#   'try',
#   'place',
#   'significant',
#   'move',
#   'mother',
#   'pattern',
#   'contain',
#   'thousand',
#   'threat',
#   'animal',
#   'another',
#   'study',
#   'experience',
#   'work',
#   'movement',
#   'end',
#   'thousand',
#   'assume',
#   'model',
#   'case',
#   'improve',
#   'century',
#   'republican',
#   'consider',
#   'total',
#   'writer',
#   'policy',
#   'without',
#   'century',
#   'defense',
#   'chair',
#   'discussion',
#   'staff',
#   'recent',
#   'another',
#   'reason',
#   'use',
#   'series',
#   'drive',
#   'scientist'],
#  ['federal',
#   'security',
#   'compare',
#   'operation',
#   'position',
#   'move',
#   'join',
#   'program',
#   'several',
#   'approach',
#   'available',
#   'job',
#   'air',
#   'hospital',
#   'task',
#   'worry',
#   'hear',
#   'development',
#   'anyone',
#   'draw',
#   'part',
#   'represent',
#   'common',
#   'rich',
#   'lot',
#   'source',
#   'food',
#   'service',
#   'including',
#   'point',
#   'door',
#   'decision',
#   'scene',
#   'political',
#   'modern',
#   'necessary'],
#  ['cell',
#   'hard',
#   'writer',
#   'letter',
#   'enter',
#   'house',
#   'school',
#   'true',
#   'present',
#   'letter',
#   'eat',
#   'doctor',
#   'article',
#   'born',
#   'sea',
#   'determine',
#   'rule',
#   'account',
#   'recently',
#   'fill',
#   'decision',
#   'cost',
#   'lay',
#   'gas',
#   'approach',
#   'meet',
#   'process',
#   'away',
#   'good',
#   'player',
#   'bar',
#   'anything',
#   'step',
#   'free',
#   'popular',
#   'large',
#   'similar',
#   'mouth',
#   'computer'],
#  ['letter',
#   'mean',
#   'attack',
#   'network',
#   'begin',
#   'exactly',
#   'marriage',
#   'movie',
#   'local',
#   'risk',
#   'relationship',
#   'worry',
#   'course',
#   'everything',
#   'even',
#   'whether',
#   'last',
#   'carry',
#   'live',
#   'mother',
#   'sport',
#   'war',
#   'college',
#   'follow',
#   'office',
#   'anything',
#   'wind',
#   'claim',
#   'clear',
#   'believe',
#   'challenge',
#   'apply',
#   'industry',
#   'eat',
#   'people',
#   'attention',
#   'catch',
#   'music',
#   'model',
#   'view',
#   'enough',
#   'show',
#   'want',
#   'kind',
#   'total',
#   'region',
#   'clearly',
#   'pretty',
#   'defense',
#   'machine',
#   'easy',
#   'discover'],
#  ['man',
#   'raise',
#   'arm',
#   'nice',
#   'really',
#   'mr',
#   'effect',
#   'talk',
#   'miss',
#   'home',
#   'end',
#   'cover',
#   'avoid',
#   'team',
#   'early',
#   'item',
#   'base',
#   'one',
#   'seem',
#   'lot',
#   'lot',
#   'owner',
#   'could',
#   'current',
#   'may',
#   'hair',
#   'police',
#   'person',
#   'mouth',
#   'guess',
#   'weight',
#   'somebody',
#   'social',
#   'rest',
#   'skill',
#   'federal',
#   'model',
#   'deep',
#   'surface',
#   'life',
#   'campaign'],
#  ['food',
#   'voice',
#   'long',
#   'response',
#   'power',
#   'late',
#   'peace',
#   'could',
#   'system',
#   'church',
#   'poor',
#   'education',
#   'employee',
#   'administration',
#   'lawyer',
#   'take',
#   'son',
#   'best',
#   'congress',
#   'piece',
#   'high',
#   'method',
#   'music',
#   'player',
#   'ready',
#   'rather',
#   'value',
#   'meeting',
#   'prove',
#   'available',
#   'wear',
#   'special',
#   'rich',
#   'improve',
#   'place',
#   'bit'],
#  ['public',
#   'environment',
#   'couple',
#   'professional',
#   'body',
#   'interview',
#   'safe',
#   'bag',
#   'fight',
#   'majority',
#   'public',
#   'finally',
#   'almost',
#   'scientist',
#   'structure',
#   'level',
#   'pick',
#   'art',
#   'quite',
#   'summer',
#   'adult',
#   'lay',
#   'resource',
#   'high',
#   'life',
#   'close',
#   'worry',
#   'maybe',
#   'low',
#   'congress',
#   'break',
#   'study',
#   'action',
#   'human'],
#  ['production',
#   'unit',
#   'although',
#   'wide',
#   'experience',
#   'old',
#   'draw',
#   'trial',
#   'sell',
#   'protect',
#   'place',
#   'result',
#   'social',
#   'industry',
#   'half',
#   'many',
#   'think',
#   'test',
#   'data',
#   'discussion',
#   'book',
#   'least',
#   'leader',
#   'control',
#   'within',
#   'study',
#   'single',
#   'exactly',
#   'three',
#   'four',
#   'scientist',
#   'well'],
#  ['fast',
#   'leg',
#   'trade',
#   'able',
#   'behavior',
#   'fight',
#   'never',
#   'air',
#   'fine',
#   'guess',
#   'toward',
#   'society',
#   'edge',
#   'green',
#   'recognize',
#   'must',
#   'safe',
#   'consumer',
#   'another',
#   'easy',
#   'put',
#   'plan',
#   'room',
#   'old',
#   'specific',
#   'act',
#   'investment',
#   'attack',
#   'sometimes',
#   'majority',
#   'performance',
#   'always',
#   'investment',
#   'section',
#   'always',
#   'road',
#   'relationship',
#   'high',
#   'concern',
#   'return',
#   'low',
#   'give',
#   'physical',
#   'civil',
#   'seven',
#   'always',
#   'agree',
#   'send',
#   'spring',
#   'current',
#   'citizen',
#   'explain',
#   'last',
#   'owner',
#   'air',
#   'firm',
#   'type',
#   'individual',
#   'light',
#   'vote',
#   'within',
#   'art',
#   'role'],
#  ['method',
#   'officer',
#   'rest',
#   'especially',
#   'investment',
#   'listen',
#   'majority',
#   'yet',
#   'recently',
#   'season',
#   'treatment',
#   'happen',
#   'pattern',
#   'le',
#   'walk',
#   'yard',
#   'return',
#   'attorney',
#   'daughter',
#   'suggest',
#   'seven',
#   'spring',
#   'choose',
#   'without',
#   'provide',
#   'beat',
#   'view',
#   'various',
#   'vote',
#   'behind',
#   'hot',
#   'evening',
#   'american',
#   'person',
#   'friend',
#   'child',
#   'church',
#   'court',
#   'son',
#   'property',
#   'later',
#   'forget',
#   'feeling',
#   'commercial',
#   'eight',
#   'analysis',
#   'ready',
#   'region',
#   'include',
#   'firm',
#   'movement',
#   'carry',
#   'street',
#   'source',
#   'economy',
#   'knowledge',
#   'election',
#   'oil',
#   'individual',
#   'west',
#   'sing',
#   'red'],
#  ['give',
#   'boy',
#   'film',
#   'particularly',
#   'style',
#   'key',
#   'history',
#   'argue',
#   'station',
#   'term',
#   'past',
#   'several',
#   'stand',
#   'attorney',
#   'receive',
#   'democrat',
#   'indicate',
#   'avoid',
#   'environment',
#   'hot',
#   'close',
#   'include',
#   'stay',
#   'present',
#   'civil',
#   'true',
#   'available',
#   'federal',
#   'staff',
#   'investment',
#   'light',
#   'plant',
#   'gas',
#   'rest',
#   'east',
#   'start',
#   'alone',
#   'growth',
#   'news',
#   'industry',
#   'small',
#   'difficult',
#   'call',
#   'next',
#   'development',
#   'rate',
#   'peace',
#   'official',
#   'policy',
#   'hair',
#   'eight',
#   'able',
#   'money',
#   'place'],
#  ['cold',
#   'six',
#   'water',
#   'eight',
#   'full',
#   'environment',
#   'notice',
#   'save',
#   'recently',
#   'sport',
#   'outside',
#   'old',
#   'instead',
#   'loss',
#   'animal',
#   'site',
#   'hard',
#   'risk',
#   'nature',
#   'family',
#   'news',
#   'mention',
#   'good',
#   'create',
#   'necessary',
#   'available',
#   'nothing',
#   'structure',
#   'road',
#   'instead',
#   'movie',
#   'total',
#   'mr',
#   'woman',
#   'bring',
#   'let',
#   'debate',
#   'around',
#   'standard',
#   'ground',
#   'prepare'],
#  ['agent',
#   'manager',
#   'sit',
#   'visit',
#   'drive',
#   'several',
#   'travel',
#   'name',
#   'place',
#   'open',
#   'state',
#   'local',
#   'nearly',
#   'follow',
#   'scientist',
#   'yes',
#   'modern',
#   'scene',
#   'try',
#   'owner',
#   'simple',
#   'hold',
#   'next',
#   'water',
#   'capital',
#   'agency',
#   'financial',
#   'push',
#   'three',
#   'animal',
#   'including',
#   'serious',
#   'play',
#   'pick',
#   'however',
#   'mention',
#   'inside',
#   'collection',
#   'authority',
#   'represent',
#   'expect',
#   'save',
#   'major',
#   'third',
#   'culture',
#   'reality'],
#  ['option',
#   'company',
#   'message',
#   'research',
#   'try',
#   'memory',
#   'carry',
#   'health',
#   'start',
#   'strong',
#   'sure',
#   'medium',
#   'kind',
#   'six',
#   'anyone',
#   'central',
#   'nice',
#   'mr',
#   'newspaper',
#   'candidate',
#   'activity',
#   'break',
#   'fund',
#   'establish',
#   'reduce',
#   'none',
#   'green',
#   'really',
#   'material',
#   'street',
#   'good',
#   'sense',
#   'institution',
#   'worry',
#   'imagine',
#   'old',
#   'list',
#   'subject',
#   'computer',
#   'college',
#   'travel',
#   'need',
#   'site',
#   'theory',
#   'value',
#   'election',
#   'read',
#   'history',
#   'possible',
#   'drive',
#   'give',
#   'maybe',
#   'clear',
#   'million',
#   'clear',
#   'measure'],
#  ['company',
#   'baby',
#   'base',
#   'practice',
#   'increase',
#   'list',
#   'bag',
#   'someone',
#   'safe',
#   'third',
#   'soon',
#   'sit',
#   'sea',
#   'student',
#   'specific',
#   'week',
#   'article',
#   'sea',
#   'probably',
#   'stop',
#   'alone',
#   'key',
#   'mean',
#   'morning',
#   'walk',
#   'clearly',
#   'federal',
#   'art',
#   'exactly',
#   'measure',
#   'coach',
#   'head',
#   'perform',
#   'moment',
#   'open',
#   'professor',
#   'allow',
#   'indeed',
#   'measure',
#   'anything',
#   'task',
#   'road',
#   'ball',
#   'degree',
#   'price',
#   'east',
#   'policy',
#   'president',
#   'affect',
#   'right',
#   'produce',
#   'democrat',
#   'upon',
#   'million',
#   'past',
#   'although',
#   'avoid',
#   'cut',
#   'feel',
#   'appear',
#   'recent',
#   'exactly',
#   'dinner',
#   'sit',
#   'step'],
#  ['year',
#   'crime',
#   'leader',
#   'history',
#   'course',
#   'everybody',
#   'instead',
#   'operation',
#   'hold',
#   'training',
#   'think',
#   'ask',
#   'week',
#   'action',
#   'moment',
#   'economy',
#   'yes',
#   'party',
#   'kind',
#   'form',
#   'small',
#   'modern',
#   'stage',
#   'read',
#   'anything',
#   'response',
#   'sound',
#   'message',
#   'reduce',
#   'little',
#   'make',
#   'man',
#   'member',
#   'case',
#   'structure',
#   'recognize',
#   'box',
#   'southern',
#   'tree',
#   'picture',
#   'billion',
#   'part',
#   'nothing',
#   'bit'],
#  ['interview',
#   'action',
#   'around',
#   'consider',
#   'establish',
#   'top',
#   'clear',
#   'agree',
#   'garden',
#   'sister',
#   'allow',
#   'conference',
#   'image',
#   'church',
#   'grow',
#   'ok',
#   'drug',
#   'decade',
#   'within',
#   'reason',
#   'population',
#   'available',
#   'assume',
#   'note',
#   'strategy',
#   'research',
#   'mention',
#   'foot',
#   'certainly'],
#  ['mother',
#   'simply',
#   'set',
#   'since',
#   'movement',
#   'report',
#   'difference',
#   'science',
#   'lay',
#   'remember',
#   'guess',
#   'million',
#   'big',
#   'wind',
#   'notice',
#   'teach',
#   'begin',
#   'senior',
#   'goal',
#   'race',
#   'u',
#   'need',
#   'rise',
#   'believe',
#   'determine',
#   'rock',
#   'energy',
#   'radio',
#   'politics',
#   'community',
#   'already',
#   'lawyer',
#   'evidence',
#   'name',
#   'answer',
#   'tend',
#   'tax',
#   'visit',
#   'republican',
#   'letter',
#   'value',
#   'show'],
#  ['material',
#   'along',
#   'help',
#   'service',
#   'either',
#   'either',
#   'claim',
#   'new',
#   'like',
#   'soldier',
#   'focus',
#   'campaign',
#   'time',
#   'pretty',
#   'voice',
#   'best',
#   'center',
#   'later',
#   'lot',
#   'case',
#   'woman',
#   'include',
#   'deal',
#   'play',
#   'affect',
#   'project',
#   'system',
#   'effect',
#   'large',
#   'possible',
#   'strong',
#   'citizen',
#   'already',
#   'old',
#   'wind',
#   'political',
#   'five',
#   'single',
#   'prepare',
#   'season',
#   'sport',
#   'clear',
#   'trial',
#   'time',
#   'book',
#   'law'],
#  ['production',
#   'way',
#   'house',
#   'use',
#   'state',
#   'audience',
#   'affect',
#   'contain',
#   'remain',
#   'unit',
#   'identify',
#   'role',
#   'process',
#   'training',
#   'pick',
#   'participant',
#   'poor',
#   'structure',
#   'create',
#   'however',
#   'minute',
#   'stop',
#   'sense',
#   'person',
#   'pay',
#   'character',
#   'interest',
#   'information',
#   'school',
#   'power',
#   'second',
#   'anything'],
#  ['south',
#   'receive',
#   'knowledge',
#   'lose',
#   'claim',
#   'ago',
#   'bad',
#   'official',
#   'artist',
#   'man',
#   'risk',
#   'range',
#   'probably',
#   'concern',
#   'live',
#   'theory',
#   'traditional',
#   'foreign',
#   'set',
#   'public',
#   'player',
#   'theory',
#   'brother',
#   'hear',
#   'administration',
#   'low',
#   'guy',
#   'instead',
#   'line',
#   'style',
#   'matter',
#   'chair',
#   'reflect',
#   'task',
#   'positive'],
#  ['run',
#   'already',
#   'economic',
#   'every',
#   'particularly',
#   'office',
#   'le',
#   'economic',
#   'foreign',
#   'individual',
#   'factor',
#   'despite',
#   'sport',
#   'majority',
#   'think',
#   'prepare',
#   'difference',
#   'u',
#   'language',
#   'tough',
#   'guess',
#   'race',
#   'protect',
#   'money',
#   'senior',
#   'move',
#   'election',
#   'view',
#   'show',
#   'civil',
#   'nearly',
#   'measure',
#   'term',
#   'six'],
#  ['finally',
#   'hotel',
#   'address',
#   'sea',
#   'none',
#   'every',
#   'gun',
#   'court',
#   'remember',
#   'often',
#   'really',
#   'rest',
#   'ask',
#   'though',
#   'face',
#   'information',
#   'state',
#   'story',
#   'economy',
#   'resource',
#   'whose',
#   'treatment',
#   'area',
#   'network',
#   'economy',
#   'fine',
#   'opportunity',
#   'american',
#   'gas',
#   'low',
#   'bit',
#   'probably',
#   'power',
#   'camera',
#   'degree',
#   'lose',
#   'stuff',
#   'word',
#   'five',
#   'painting',
#   'issue',
#   'occur'],
#  ['although',
#   'within',
#   'issue',
#   'tell',
#   'exactly',
#   'south',
#   'kid',
#   'discussion',
#   'foot',
#   'organization',
#   'site',
#   'owner',
#   'trade',
#   'strategy',
#   'price',
#   'wide',
#   'war',
#   'reality',
#   'represent',
#   'success',
#   'two',
#   'dream',
#   'day',
#   'score',
#   'smile',
#   'month',
#   'together',
#   'box',
#   'voice',
#   'mr',
#   'beyond',
#   'song',
#   'go',
#   'management',
#   'address',
#   'almost',
#   'always',
#   'much',
#   'sign',
#   'high',
#   'keep',
#   'buy',
#   'easy',
#   'pretty',
#   'prepare',
#   'arm',
#   'agent',
#   'dinner',
#   'campaign',
#   'nice',
#   'forget',
#   'within',
#   'training'],
#  ['watch',
#   'right',
#   'bar',
#   'reality',
#   'one',
#   'knowledge',
#   'player',
#   'last',
#   'across',
#   'name',
#   'good',
#   'environment',
#   'sea',
#   'safe',
#   'visit',
#   'central',
#   'one',
#   'voice',
#   'use',
#   'cup',
#   'arm',
#   'avoid',
#   'cut',
#   'boy',
#   'civil',
#   'effect',
#   'answer',
#   'care',
#   'night',
#   'assume',
#   'present',
#   'consider',
#   'seek',
#   'agreement',
#   'ability',
#   'south',
#   'executive',
#   'usually',
#   'race',
#   'week',
#   'parent',
#   'difficult',
#   'family',
#   'soon',
#   'research'],
#  ['either',
#   'culture',
#   'federal',
#   'ten',
#   'middle',
#   'hit',
#   'commercial',
#   'instead',
#   'law',
#   'clearly',
#   'claim',
#   'mr',
#   'family',
#   'perform',
#   'daughter',
#   'bar',
#   'drug',
#   'professor',
#   'spend',
#   'book',
#   'let',
#   'glass',
#   'indicate',
#   'authority',
#   'top',
#   'shake',
#   'account',
#   'quickly',
#   'performance',
#   'indicate',
#   'family',
#   'wind',
#   'stuff',
#   'key',
#   'rate',
#   'explain',
#   'weight',
#   'care',
#   'even',
#   'live',
#   'suddenly',
#   'movie',
#   'whether',
#   'week',
#   'together',
#   'weight',
#   'peace',
#   'enjoy',
#   'car',
#   'baby',
#   'yeah',
#   'six',
#   'impact',
#   'trade',
#   'tell',
#   'parent',
#   'group'],
#  ['heavy',
#   'miss',
#   'cup',
#   'view',
#   'record',
#   'choose',
#   'per',
#   'value',
#   'must',
#   'billion',
#   'common',
#   'loss',
#   'four',
#   'condition',
#   'director',
#   'laugh',
#   'democrat',
#   'mean',
#   'next',
#   'particular',
#   'magazine',
#   'industry',
#   'firm',
#   'former',
#   'magazine',
#   'thousand',
#   'former',
#   'economy',
#   'central',
#   'everyone',
#   'security',
#   'civil',
#   'name',
#   'go',
#   'sound',
#   'new',
#   'popular',
#   'meeting',
#   'walk',
#   'ground',
#   'issue',
#   'feeling',
#   'join',
#   'single',
#   'pressure',
#   'fly',
#   'food',
#   'organization',
#   'customer',
#   'budget',
#   'dog',
#   'school',
#   'source',
#   'trip'],
#  ['drug',
#   'modern',
#   'culture',
#   'build',
#   'history',
#   'eye',
#   'teach',
#   'factor',
#   'effort',
#   'sound',
#   'right',
#   'stage',
#   'lot',
#   'affect',
#   'street',
#   'wrong',
#   'kind',
#   'management'],
#  ['future',
#   'certainly',
#   'door',
#   'authority',
#   'fish',
#   'night',
#   'meeting',
#   'space',
#   'half',
#   'cause',
#   'public',
#   'industry',
#   'involve',
#   'certainly',
#   'official',
#   'effort',
#   'great',
#   'speak',
#   'professional',
#   'politics',
#   'board',
#   'lay',
#   'force',
#   'attention',
#   'region',
#   'quickly',
#   'window',
#   'full'],
#  ['parent',
#   'soldier',
#   'loss',
#   'attorney',
#   'training',
#   'run',
#   'behavior',
#   'day',
#   'industry',
#   'receive',
#   'window',
#   'property',
#   'red',
#   'close',
#   'several',
#   'include'],
#  ['opportunity',
#   'college',
#   'place',
#   'ball',
#   'wife',
#   'blue',
#   'gas',
#   'message',
#   'evening',
#   'month',
#   'interesting',
#   'letter',
#   'car',
#   'special',
#   'rock',
#   'short',
#   'game',
#   'marriage'],
#  ['likely',
#   'deal',
#   'black',
#   'investment',
#   'moment',
#   'issue',
#   'learn',
#   'receive',
#   'goal',
#   'reality',
#   'never',
#   'subject',
#   'couple',
#   'early',
#   'water',
#   'back',
#   'sound',
#   'couple',
#   'record',
#   'wrong',
#   'recently',
#   'small',
#   'else',
#   'admit',
#   'success',
#   'choice',
#   'something',
#   'picture'],
#  ['east',
#   'exist',
#   'drop',
#   'growth',
#   'feel',
#   'pretty',
#   'reduce',
#   'hospital',
#   'box',
#   'account',
#   'consumer',
#   'century',
#   'old',
#   'mention',
#   'story',
#   'tell',
#   'behavior',
#   'relate',
#   'point',
#   'man',
#   'goal',
#   'today',
#   'foreign',
#   'minute',
#   'tonight',
#   'pm',
#   'easy'],
#  ['science',
#   'realize',
#   'positive',
#   'doctor',
#   'market',
#   'raise',
#   'resource',
#   'interesting',
#   'ready',
#   'customer',
#   'option',
#   'relationship',
#   'soldier',
#   'choose',
#   'student',
#   'old',
#   'son',
#   'prepare',
#   'green',
#   'management'],
#  ['amount',
#   'job',
#   'least',
#   'system',
#   'least',
#   'provide',
#   'tonight',
#   'special',
#   'fill',
#   'personal',
#   'others',
#   'consumer',
#   'place',
#   'must',
#   'east',
#   'nice',
#   'within',
#   'performance',
#   'model',
#   'security',
#   'size',
#   'kitchen',
#   'international',
#   'mission',
#   'skill',
#   'sure',
#   'popular',
#   'save',
#   'forget',
#   'peace',
#   'care',
#   'race',
#   'question',
#   'congress'],
#  ['consider',
#   'former',
#   'entire',
#   'stand',
#   'occur',
#   'radio',
#   'ten',
#   'place',
#   'growth',
#   'student',
#   'state',
#   'choice',
#   'figure',
#   'loss',
#   'return',
#   'friend'],
#  ['lawyer',
#   'official',
#   'nature',
#   'simply',
#   'wide',
#   'anything',
#   'throughout',
#   'forget',
#   'food',
#   'crime',
#   'general'],
#  ['meeting',
#   'get',
#   'model',
#   'leader',
#   'bring',
#   'conference',
#   'vote',
#   'involve',
#   'size',
#   'floor',
#   'recognize',
#   'act',
#   'girl',
#   'federal',
#   'government'],
#  ['create',
#   'increase',
#   'morning',
#   'within',
#   'dinner',
#   'purpose',
#   'modern',
#   'least',
#   'agreement',
#   'remember',
#   'executive',
#   'young',
#   'fine',
#   'money',
#   'fine',
#   'girl',
#   'reflect',
#   'learn',
#   'seven',
#   'visit',
#   'speech',
#   'guess',
#   'task',
#   'young',
#   'least',
#   'identify',
#   'pull',
#   'hospital'],
#  ['clearly',
#   'economy',
#   'school',
#   'live',
#   'next',
#   'value',
#   'environment',
#   'seek',
#   'turn',
#   'republican',
#   'assume',
#   'six',
#   'every',
#   'follow',
#   'commercial',
#   'head',
#   'purpose',
#   'measure',
#   'officer',
#   'sound',
#   'make',
#   'door',
#   'street',
#   'collection',
#   'effect',
#   'executive',
#   'think',
#   'little'],
#  ['information',
#   'apply',
#   'require',
#   'traditional',
#   'note',
#   'attack',
#   'develop',
#   'probably',
#   'together',
#   'necessary',
#   'focus',
#   'feel',
#   'commercial',
#   'relate',
#   'sea',
#   'quite',
#   'meet',
#   'year',
#   'perhaps',
#   'special',
#   'bed',
#   'result',
#   'true',
#   'believe',
#   'possible',
#   'manager',
#   'stand',
#   'million',
#   'good',
#   'report',
#   'film'],
#  ['hour',
#   'run',
#   'arrive',
#   'moment',
#   'short',
#   'detail',
#   'feeling',
#   'fire',
#   'admit',
#   'wide',
#   'court',
#   'relationship',
#   'prevent',
#   'american',
#   'strong',
#   'quality',
#   'enter'],
#  ['friend',
#   'behavior',
#   'carry',
#   'culture',
#   'model',
#   'end',
#   'story',
#   'education',
#   'body',
#   'continue',
#   'price',
#   'money',
#   'never',
#   'fear',
#   'start',
#   'grow',
#   'draw',
#   'talk',
#   'clearly'],
#  ['social',
#   'suddenly',
#   'approach',
#   'leave',
#   'teacher',
#   'account',
#   'probably',
#   'price',
#   'remain',
#   'someone',
#   'board',
#   'mission',
#   'keep',
#   'high',
#   'drop',
#   'possible',
#   'enough',
#   'receive',
#   'others',
#   'stuff',
#   'growth',
#   'believe'],
#  ['decide',
#   'yes',
#   'kid',
#   'piece',
#   'first',
#   'window',
#   'risk',
#   'newspaper',
#   'wish',
#   'west',
#   'scientist',
#   'reduce',
#   'lawyer',
#   'toward',
#   'politics',
#   'quickly',
#   'record',
#   'entire',
#   'grow',
#   'movement',
#   'six',
#   'ask',
#   'thing',
#   'provide',
#   'floor',
#   'spend',
#   'recent',
#   'million',
#   'foreign',
#   'lot',
#   'simply',
#   'lead'],
#  ['role',
#   'money',
#   'medium',
#   'continue',
#   'first',
#   'visit',
#   'chair',
#   'drop',
#   'yes',
#   'sort',
#   'perform',
#   'wear',
#   'car',
#   'design',
#   'half',
#   'light',
#   'loss',
#   'certain',
#   'phone',
#   'wall',
#   'gas',
#   'east',
#   'everything',
#   'board',
#   'art',
#   'put',
#   'director',
#   'ago',
#   'short'],
#  ['wall',
#   'week',
#   'citizen',
#   'someone',
#   'win',
#   'difference',
#   'woman',
#   'month',
#   'student',
#   'character',
#   'source',
#   'reality',
#   'exist',
#   'necessary',
#   'outside',
#   'machine',
#   'road',
#   'brother',
#   'board',
#   'soldier',
#   'bar',
#   'oil',
#   'series',
#   'voice',
#   'stop',
#   'structure',
#   'country',
#   'language',
#   'remember',
#   'skill',
#   'according',
#   'method',
#   'entire',
#   'want',
#   'hospital'],
#  ['night',
#   'idea',
#   'describe',
#   'writer',
#   'pay',
#   'would',
#   'pull',
#   'mr',
#   'science',
#   'deep',
#   'process',
#   'improve',
#   'peace',
#   'return',
#   'little',
#   'room',
#   'affect',
#   'trade',
#   'act',
#   'evidence',
#   'word',
#   'old',
#   'real',
#   'position',
#   'impact',
#   'security',
#   'throughout',
#   'mean',
#   'form',
#   'recognize',
#   'letter',
#   'maybe',
#   'play',
#   'news'],
#  ['best',
#   'suddenly',
#   'always',
#   'worry',
#   'baby',
#   'knowledge',
#   'decide',
#   'term',
#   'pressure',
#   'control',
#   'particular',
#   'perhaps',
#   'around',
#   'couple',
#   'rock',
#   'able',
#   'visit',
#   'blood',
#   'capital',
#   'necessary',
#   'people',
#   'month',
#   'mention',
#   'rate',
#   'open',
#   'main',
#   'prove',
#   'else',
#   'reason',
#   'population'],
#  ['artist',
#   'someone',
#   'others',
#   'note',
#   'although',
#   'partner',
#   'arm',
#   'impact',
#   'side',
#   'tell',
#   'event',
#   'southern',
#   'sound',
#   'hope',
#   'letter',
#   'sense',
#   'far',
#   'including',
#   'current',
#   'turn',
#   'test',
#   'account',
#   'score'],
#  ['early',
#   'continue',
#   'detail',
#   'treat',
#   'reveal',
#   'finish',
#   'consumer',
#   'general',
#   'economic',
#   'price',
#   'surface',
#   'thus',
#   'business',
#   'deep',
#   'law',
#   'hotel',
#   'congress',
#   'message',
#   'special',
#   'full',
#   'act',
#   'common',
#   'fight',
#   'bit',
#   'want',
#   'management',
#   'recognize',
#   'black',
#   'strategy',
#   'degree',
#   'none',
#   'lawyer',
#   'performance',
#   'ever',
#   'front',
#   'example',
#   'century',
#   'together',
#   'prepare',
#   'radio'],
#  ['detail',
#   'already',
#   'option',
#   'lawyer',
#   'modern',
#   'staff',
#   'life',
#   'executive',
#   'win',
#   'pull',
#   'far',
#   'fact',
#   'ready',
#   'wish',
#   'movement',
#   'growth',
#   'everybody',
#   'edge',
#   'figure',
#   'owner',
#   'impact',
#   'employee',
#   'total',
#   'yeah',
#   'help',
#   'police',
#   'lawyer',
#   'show',
#   'green',
#   'growth',
#   'unit',
#   'improve',
#   'hospital',
#   'rule',
#   'determine'],
#  ['fine',
#   'throughout',
#   'market',
#   'player',
#   'size',
#   'civil',
#   'color',
#   'record',
#   'study',
#   'answer',
#   'agreement',
#   'television',
#   'subject',
#   'detail',
#   'plan',
#   'almost',
#   'debate',
#   'prepare',
#   'vote',
#   'grow',
#   'play',
#   'tv',
#   'catch',
#   'southern',
#   'current',
#   'quickly',
#   'back',
#   'detail',
#   'detail'],
#  ['music',
#   'among',
#   'form',
#   'reach',
#   'guess',
#   'evidence',
#   'treatment',
#   'share',
#   'according',
#   'even',
#   'goal',
#   'force',
#   'conference',
#   'board',
#   'whose',
#   'special',
#   'statement',
#   'none',
#   'study',
#   'front',
#   'suffer',
#   'need',
#   'evidence',
#   'popular',
#   'nice',
#   'author',
#   'house',
#   'agreement',
#   'building',
#   'city',
#   'human',
#   'since',
#   'care',
#   'still',
#   'mouth',
#   'school',
#   'nearly',
#   'act',
#   'fund',
#   'vote'],
#  ['seven',
#   'money',
#   'prevent',
#   'eat',
#   'fact',
#   'free',
#   'pretty',
#   'bank',
#   'painting',
#   'land',
#   'information',
#   'focus',
#   'color',
#   'middle',
#   'name',
#   'serious',
#   'possible',
#   'answer',
#   'person',
#   'serve',
#   'adult',
#   'strong',
#   'knowledge',
#   'action',
#   'plant',
#   'buy',
#   'main',
#   'husband',
#   'kitchen',
#   'call',
#   'room',
#   'raise',
#   'challenge'],
#  ['tv',
#   'employee',
#   'environment',
#   'site',
#   'behind',
#   'else',
#   'mention',
#   'personal',
#   'catch',
#   'eye',
#   'black',
#   'whatever',
#   'father',
#   'join',
#   'know',
#   'first',
#   'u',
#   'success',
#   'wish',
#   'parent',
#   'anything'],
#  ['single',
#   'reality',
#   'partner',
#   'behavior',
#   'least',
#   'strong',
#   'stage',
#   'cup',
#   'especially',
#   'way',
#   'hot',
#   'century',
#   'agency',
#   'republican',
#   'catch',
#   'give',
#   'energy',
#   'candidate',
#   'card',
#   'collection',
#   'president',
#   'trip',
#   'study',
#   'democratic',
#   'way',
#   'person',
#   'manager',
#   'though',
#   'next',
#   'really',
#   'personal',
#   'suffer',
#   'pm',
#   'better',
#   'option',
#   'opportunity',
#   'determine',
#   'wait',
#   'record',
#   'like',
#   'person',
#   'magazine'],
#  ['policy',
#   'main',
#   'dark',
#   'home',
#   'season',
#   'either',
#   'player',
#   'never',
#   'reveal',
#   'dream',
#   'woman',
#   'say',
#   'institution',
#   'husband',
#   'second',
#   'wish',
#   'new',
#   'speak',
#   'little',
#   'program',
#   'add',
#   'set',
#   'total',
#   'scene',
#   'recent',
#   'weight',
#   'final',
#   'share',
#   'half',
#   'president',
#   'consumer',
#   'spring',
#   'reflect',
#   'half',
#   'loss',
#   'guess'],
#  ['score',
#   'expert',
#   'three',
#   'early',
#   'week',
#   'tell',
#   'reveal',
#   'think',
#   'serve',
#   'support',
#   'test',
#   'former',
#   'particularly',
#   'finally',
#   'edge',
#   'item',
#   'kitchen',
#   'week',
#   'right',
#   'raise',
#   'event',
#   'best',
#   'care',
#   'including',
#   'easy',
#   'staff',
#   'speak',
#   'single',
#   'best',
#   'market',
#   'fund'],
#  ['artist',
#   'station',
#   'chair',
#   'happen',
#   'along',
#   'ready',
#   'democratic',
#   'player',
#   'international',
#   'ever',
#   'table',
#   'build',
#   'sort',
#   'hotel',
#   'end',
#   'hotel',
#   'different',
#   'stop',
#   'medium',
#   'church',
#   'say',
#   'fine',
#   'theory',
#   'game',
#   'across',
#   'story',
#   'walk',
#   'remember',
#   'enough',
#   'today',
#   'keep',
#   'street'],
#  ['fast',
#   'box',
#   'program',
#   'trial',
#   'building',
#   'everyone',
#   'state',
#   'resource',
#   'exactly',
#   'avoid',
#   'former',
#   'rule',
#   'bad',
#   'stock',
#   'indeed',
#   'skin',
#   'thousand',
#   'many',
#   'save',
#   'goal',
#   'drop',
#   'camera',
#   'skill',
#   'serious',
#   'forward',
#   'develop',
#   'player',
#   'sit',
#   'pull',
#   'pull',
#   'significant',
#   'population',
#   'road',
#   'reach',
#   'ball',
#   'whose',
#   'pm',
#   'writer',
#   'real',
#   'message',
#   'research'],
#  ['customer',
#   'never',
#   'time',
#   'issue',
#   'recent',
#   'order',
#   'station',
#   'chair',
#   'interest',
#   'born',
#   'cultural',
#   'capital',
#   'religious',
#   'know',
#   'various',
#   'information',
#   'senior',
#   'future',
#   'purpose',
#   'none',
#   'current',
#   'everyone',
#   'medium',
#   'mr',
#   'drop',
#   'difficult',
#   'environmental',
#   'either',
#   'talk',
#   'top',
#   'case',
#   'want',
#   'cause',
#   'six',
#   'defense',
#   'two',
#   'watch'],
#  ['kind',
#   'wait',
#   'lay',
#   'local',
#   'wonder',
#   'husband',
#   'nice',
#   'relate',
#   'particularly',
#   'notice',
#   'something',
#   'join',
#   'house',
#   'work',
#   'rate',
#   'family',
#   'fire',
#   'great',
#   'two',
#   'identify',
#   'white',
#   'small',
#   'song',
#   'determine',
#   'remain',
#   'run',
#   'several',
#   'allow',
#   'anyone',
#   'throw',
#   'grow',
#   'whatever',
#   'end',
#   'mission',
#   'break',
#   'term',
#   'article',
#   'measure',
#   'matter',
#   'end',
#   'seem',
#   'agent',
#   'move',
#   'benefit',
#   'game',
#   'radio'],
#  ['short',
#   'beat',
#   'cold',
#   'environmental',
#   'wrong',
#   'pm',
#   'wear',
#   'return',
#   'father',
#   'another',
#   'green',
#   'send',
#   'mr',
#   'dream',
#   'six',
#   'local',
#   'nice',
#   'determine',
#   'various',
#   'green',
#   'bring',
#   'per',
#   'college',
#   'approach',
#   'onto',
#   'town',
#   'unit',
#   'cup',
#   'note',
#   'help',
#   'top',
#   'seat',
#   'hear',
#   'spend',
#   'health',
#   'movement',
#   'join',
#   'water',
#   'rock',
#   'difficult',
#   'nearly',
#   'project',
#   'major',
#   'rule',
#   'pattern',
#   'leader',
#   'present',
#   'adult',
#   'soon',
#   'official',
#   'instead',
#   'treatment',
#   'turn',
#   'western',
#   'race',
#   'positive',
#   'individual',
#   'reach',
#   'glass',
#   'boy'],
#  ['movement',
#   'million',
#   'science',
#   'sometimes',
#   'provide',
#   'type',
#   'site',
#   'author',
#   'defense',
#   'result',
#   'church',
#   'take',
#   'experience',
#   'take',
#   'high',
#   'authority',
#   'like',
#   'find',
#   'particularly',
#   'buy',
#   'able',
#   'executive',
#   'per',
#   'paper',
#   'public',
#   'sing',
#   'consumer',
#   'table',
#   'despite',
#   'mother',
#   'hair',
#   'drop',
#   'seven',
#   'program',
#   'consumer',
#   'book',
#   'federal',
#   'lawyer',
#   'right',
#   'focus',
#   'consumer',
#   'land',
#   'another',
#   'laugh',
#   'prevent',
#   'seven',
#   'recently',
#   'politics',
#   'whose',
#   'agree',
#   'buy',
#   'indicate',
#   'eat',
#   'evidence',
#   'official'],
#  ['small',
#   'military',
#   'use',
#   'type',
#   'top',
#   'quality',
#   'free',
#   'away',
#   'truth',
#   'week',
#   'turn',
#   'safe',
#   'skin',
#   'huge',
#   'large',
#   'boy',
#   'hotel',
#   'even',
#   'miss',
#   'doctor',
#   'degree',
#   'machine',
#   'fact',
#   'race',
#   'soon',
#   'training',
#   'establish',
#   'southern',
#   'quickly',
#   'first',
#   'modern',
#   'modern',
#   'gas',
#   'turn',
#   'peace',
#   'see',
#   'specific',
#   'republican',
#   'mr',
#   'music',
#   'pull',
#   'great',
#   'sign',
#   'determine',
#   'bag',
#   'phone',
#   'pretty',
#   'wish',
#   'attack'],
#  ['nature',
#   'remain',
#   'possible',
#   'court',
#   'source',
#   'concern',
#   'question',
#   'bag',
#   'others',
#   'half',
#   'third',
#   'role',
#   'thousand',
#   'beautiful',
#   'lot',
#   'argue',
#   'art',
#   'respond',
#   'believe',
#   'business',
#   'control',
#   'place',
#   'draw',
#   'evidence',
#   'free',
#   'go',
#   'toward',
#   'billion',
#   'onto',
#   'edge',
#   'medical',
#   'similar',
#   'red',
#   'account',
#   'action',
#   'whatever',
#   'family',
#   'hold',
#   'across',
#   'water',
#   'fish',
#   'establish',
#   'someone',
#   'important',
#   'sense',
#   'relate',
#   'conference',
#   'show',
#   'score',
#   'ask',
#   'allow'],
#  ['surface',
#   'accept',
#   'hour',
#   'whose',
#   'evening',
#   'ground',
#   'adult',
#   'race',
#   'sure',
#   'clearly',
#   'public',
#   'keep',
#   'organization',
#   'plant',
#   'rate',
#   'reduce',
#   'story',
#   'role',
#   'soon',
#   'assume',
#   'finally',
#   'sit',
#   'join',
#   'visit',
#   'life',
#   'open',
#   'fine',
#   'particular',
#   'health',
#   'management',
#   'check',
#   'perform',
#   'serve',
#   'really',
#   'memory',
#   'rule',
#   'laugh',
#   'often',
#   'color',
#   'special',
#   'west',
#   'property'],
#  ['mr',
#   'get',
#   'condition',
#   'lay',
#   'thought',
#   'list',
#   'must',
#   'alone',
#   'network',
#   'rather',
#   'beyond',
#   'front',
#   'surface',
#   'rule',
#   'together',
#   'ball',
#   'example',
#   'memory',
#   'animal',
#   'institution',
#   'page',
#   'plant',
#   'study',
#   'recognize',
#   'realize',
#   'conference',
#   'part',
#   'blue',
#   'machine',
#   'dream',
#   'staff',
#   'institution',
#   'board',
#   'risk',
#   'style',
#   'enjoy',
#   'believe',
#   'design',
#   'represent',
#   'tonight',
#   'nice',
#   'ahead',
#   'analysis',
#   'language',
#   'north',
#   'mr'],
#  ['three',
#   'certain',
#   'deal',
#   'dream',
#   'candidate',
#   'leave',
#   'notice',
#   'various',
#   'term',
#   'decision',
#   'since',
#   'laugh',
#   'throw',
#   'left',
#   'across',
#   'reach',
#   'start',
#   'loss',
#   'hear',
#   'plant',
# ...
#   'term',
#   'ball',
#   'third',
#   'half',
#   'answer',
#   'help',
#   'practice',
#   'spring',
#   'current',
#   'form',
#   'deep',
#   'relate',
#   'character',
#   'key',
#   'major',
#   'population',
#   'front',
#   'piece',
#   'everyone',
#   'sound',
#   'game',
#   'evidence',
#   'lot',
#   'discover',
#   'although',
#   'experience',
#   'opportunity',
#   'tell',
#   'woman',
#   'study',
#   'authority',
#   'animal',
#   'drug',
#   'foot',
#   'organization',
#   'stand',
#   'person',
#   'paper',
#   'save',
#   'make',
#   'traditional',
#   'seat'],
#  ['father',
#   'tough',
#   'attention',
#   'return',
#   'fill',
#   'perform',
#   'relate',
#   'year',
#   'writer',
#   'moment',
#   'free',
#   'matter',
#   'let',
#   'low',
#   'ok',
#   'nice',
#   'last',
#   'dog',
#   'note',
#   'behind',
#   'minute',
#   'plan',
#   'power',
#   'number',
#   'remember',
#   'ability',
#   'drive',
#   'fight',
#   'recently',
#   'interview',
#   'public',
#   'whatever',
#   'full',
#   'network',
#   'concern',
#   'north',
#   'friend',
#   'despite',
#   'fight',
#   'cut',
#   'north',
#   'page',
#   'ahead',
#   'stop',
#   'land',
#   'phone',
#   'table',
#   'last',
#   'good',
#   'despite',
#   'market',
#   'partner',
#   'management',
#   'along',
#   'next'],
#  ['policy',
#   'many',
#   'participant',
#   'eight',
#   'floor',
#   'democrat',
#   'hair',
#   'argue',
#   'per',
#   'sign',
#   'voice',
#   'know',
#   'tend',
#   'bad',
#   'lead',
#   'interest',
#   'look',
#   'among',
#   'long',
#   'technology',
#   'value',
#   'avoid',
#   'mission',
#   'reduce',
#   'light',
#   'course',
#   'direction',
#   'move',
#   'cause',
#   'control',
#   'star',
#   'bit',
#   'interest',
#   'cost',
#   'firm',
#   'fund',
#   'create',
#   'friend',
#   'defense',
#   'fish',
#   'hundred',
#   'series',
#   'fight',
#   'education',
#   'event',
#   'born',
#   'building',
#   'page',
#   'suggest',
#   'first',
#   'others',
#   'success',
#   'yet',
#   'ready',
#   'door',
#   'huge',
#   'mention',
#   'forward',
#   'effort',
#   'sport',
#   'evening'],
#  ['similar',
#   'value',
#   'minute',
#   'loss',
#   'upon',
#   'customer',
#   'fight',
#   'particular',
#   'hit',
#   'house',
#   'hope',
#   'bad',
#   'life',
#   'hour',
#   'become',
#   'mr',
#   'u',
#   'contain',
#   'pretty',
#   'summer',
#   'brother',
#   'live',
#   'main',
#   'fly',
#   'dream',
#   'trial',
#   'mind',
#   'follow',
#   'likely',
#   'however',
#   'finally',
#   'western',
#   'bag',
#   'identify',
#   'executive'],
#  ['director',
#   'agree',
#   'side',
#   'audience',
#   'loss',
#   'finally',
#   'office',
#   'prove',
#   'region',
#   'piece',
#   'toward',
#   'sense',
#   'grow',
#   'training',
#   'cut',
#   'information',
#   'positive',
#   'pm',
#   'trouble',
#   'charge',
#   'wonder',
#   'question',
#   'anyone',
#   'prevent',
#   'probably',
#   'store',
#   'break',
#   'national',
#   'agreement',
#   'main',
#   'night',
#   'large',
#   'look',
#   'continue',
#   'door',
#   'general',
#   'professor',
#   'night',
#   'upon',
#   'book',
#   'sometimes',
#   'stock',
#   'heart',
#   'wear',
#   'cup',
#   'daughter',
#   'structure',
#   'light',
#   'impact',
#   'data',
#   'method',
#   'want',
#   'inside',
#   'high',
#   'pretty',
#   'rule',
#   'region'],
#  ['movie',
#   'table',
#   'eye',
#   'ask',
#   'shoulder',
#   'investment',
#   'cold',
#   'good',
#   'make',
#   'tonight',
#   'benefit',
#   'left',
#   'plan',
#   'cell',
#   'space',
#   'appear',
#   'wrong',
#   'son',
#   'individual',
#   'power',
#   'level',
#   'guess',
#   'discussion',
#   'eye',
#   'skin',
#   'many',
#   'throw',
#   'leader',
#   'east',
#   'benefit',
#   'price',
#   'quality',
#   'standard',
#   'range',
#   'amount',
#   'something',
#   'project',
#   'reduce',
#   'character',
#   'change',
#   'product',
#   'south',
#   'score',
#   'away',
#   'expect',
#   'candidate',
#   'school',
#   'according'],
#  ['item',
#   'cut',
#   'democratic',
#   'conference',
#   'voice',
#   'vote',
#   'particularly',
#   'opportunity',
#   'energy',
#   'bed',
#   'positive',
#   'sure',
#   'father',
#   'help',
#   'beautiful',
#   'instead',
#   'remember',
#   'establish',
#   'leg',
#   'voice',
#   'cup',
#   'career',
#   'old',
#   'line',
#   'painting',
#   'big',
#   'reach',
#   'argue',
#   'relationship',
#   'successful',
#   'remember',
#   'someone',
#   'interest',
#   'contain',
#   'attorney',
#   'le',
#   'yes',
#   'loss',
#   'red',
#   'check',
#   'mind',
#   'mean',
#   'simple',
#   'evidence',
#   'writer',
#   'prevent',
#   'easy',
#   'nearly',
#   'management',
#   'onto',
#   'population',
#   'charge',
#   'sister',
#   'character',
#   'build',
#   'sound',
#   'information',
#   'partner',
#   'question',
#   'religious',
#   'cut',
#   'detail',
#   'day'],
#  ['measure',
#   'ago',
#   'center',
#   'fly',
#   'amount',
#   'cultural',
#   'treatment',
#   'father',
#   'author',
#   'learn',
#   'suggest',
#   'generation',
#   'determine',
#   'decade',
#   'sport',
#   'another',
#   'marriage',
#   'kind',
#   'miss',
#   'air',
#   'last',
#   'effect',
#   'suggest',
#   'value',
#   'civil',
#   'mother',
#   'draw',
#   'actually',
#   'note',
#   'public',
#   'agreement',
#   'sound',
#   'student',
#   'buy',
#   'affect',
#   'season',
#   'concern',
#   'child',
#   'television',
#   'training',
#   'pattern',
#   'husband',
#   'ever',
#   'change',
#   'management',
#   'page'],
#  ['senior',
#   'item',
#   'increase',
#   'carry',
#   'see',
#   'hope',
#   'poor',
#   'sell',
#   'eat',
#   'personal',
#   'lead',
#   'early',
#   'dream',
#   'nothing',
#   'former',
#   'grow',
#   'benefit',
#   'beautiful',
#   'realize',
#   'evening',
#   'common',
#   'sing',
#   'common',
#   'manager',
#   'find',
#   'improve',
#   'little',
#   'instead',
#   'authority',
#   'quite',
#   'condition',
#   'instead',
#   'huge',
#   'politics',
#   'still',
#   'audience',
#   'note',
#   'million'],
#  ['deal',
#   'draw',
#   'training',
#   'local',
#   'exist',
#   'important',
#   'state',
#   'appear',
#   'cost',
#   'candidate',
#   'nice',
#   'season',
#   'field',
#   'think',
#   'ago',
#   'especially',
#   'exist',
#   'class',
#   'mr',
#   'popular',
#   'red',
#   'season',
#   'head',
#   'situation',
#   'enough',
#   'suddenly',
#   'walk',
#   'four',
#   'cost',
#   'three',
#   'table',
#   'experience',
#   'conference',
#   'term',
#   'blood',
#   'per',
#   'various',
#   'success',
#   'eat',
#   'none',
#   'boy',
#   'hold'],
#  ['treat',
#   'million',
#   'fine',
#   'campaign',
#   'window',
#   'front',
#   'would',
#   'court',
#   'process',
#   'ask',
#   'thank',
#   'floor',
#   'structure',
#   'hard',
#   'international',
#   'care',
#   'run',
#   'catch',
#   'issue',
#   'huge',
#   'term',
#   'four',
#   'contain',
#   'relate',
#   'choose'],
#  ['hospital',
#   'trip',
#   'sing',
#   'economy',
#   'another',
#   'administration',
#   'study',
#   'war',
#   'war',
#   'challenge',
#   'arm',
#   'agency',
#   'tax',
#   'ball',
#   'second',
#   'section',
#   'owner'],
#  ['bit',
#   'ability',
#   'drop',
#   'result',
#   'morning',
#   'treat',
#   'money',
#   'chair',
#   'property',
#   'identify',
#   'shoulder',
#   'test',
#   'woman',
#   'customer',
#   'full',
#   'season',
#   'arm',
#   'often',
#   'reduce',
#   'point'],
#  ['run',
#   'teacher',
#   'character',
#   'foot',
#   'entire',
#   'perhaps',
#   'stay',
#   'carry',
#   'environmental',
#   'including',
#   'cost',
#   'pretty',
#   'five',
#   'gas',
#   'item',
#   'news',
#   'camera',
#   'occur',
#   'boy',
#   'improve',
#   'community',
#   'arrive',
#   'blood',
#   'meet',
#   'alone',
#   'concern',
#   'clear',
#   'would',
#   'positive',
#   'project'],
#  ['fly',
#   'professional',
#   'throughout',
#   'federal',
#   'five',
#   'cell',
#   'understand',
#   'american',
#   'mean',
#   'south',
#   'present',
#   'letter',
#   'collection',
#   'common',
#   'security',
#   'able',
#   'bring',
#   'consumer',
#   'beat',
#   'today',
#   'hit',
#   'sign',
#   'stage',
#   'loss',
#   'actually'],
#  ['bank',
#   'future',
#   'charge',
#   'body',
#   'decade',
#   'attention',
#   'relationship',
#   'drug',
#   'prove',
#   'u',
#   'claim',
#   'box',
#   'account',
#   'culture',
#   'cell',
#   'response',
#   'form',
#   'common',
#   'firm',
#   'leader',
#   'white',
#   'human',
#   'north',
#   'water',
#   'manage',
#   'season'],
#  ['stand',
#   'within',
#   'effect',
#   'medium',
#   'late',
#   'later',
#   'degree',
#   'instead',
#   'might',
#   'better',
#   'official',
#   'boy',
#   'one',
#   'receive',
#   'upon',
#   'conference',
#   'talk',
#   'central',
#   'staff',
#   'election',
#   'international',
#   'inside',
#   'one',
#   'teach',
#   'life',
#   'group',
#   'degree',
#   'treatment',
#   'benefit'],
#  ['short',
#   'sea',
#   'free',
#   'another',
#   'speak',
#   'generation',
#   'bit',
#   'whether',
#   'heart',
#   'six',
#   'method',
#   'work',
#   'painting',
#   'light',
#   'sense',
#   'great',
#   'foot',
#   'play',
#   'buy',
#   'discussion',
#   'audience',
#   'style',
#   'set',
#   'provide',
#   'southern',
#   'learn',
#   'son',
#   'tree',
#   'international',
#   'stage'],
#  ['ask',
#   'lose',
#   'four',
#   'national',
#   'expert',
#   'thank',
#   'list',
#   'skin',
#   'sound',
#   'make',
#   'lose',
#   'answer',
#   'sea',
#   'cost',
#   'later',
#   'past',
#   'trip',
#   'peace',
#   'likely',
#   'voice',
#   'inside',
#   'ahead',
#   'class',
#   'beyond',
#   'best',
#   'significant',
#   'letter',
#   'onto',
#   'spring',
#   'population',
#   'little',
#   'scene',
#   'meet',
#   'interest',
#   'able',
#   'six',
#   'traditional',
#   'cultural',
#   'artist',
#   'kind',
#   'similar'],
#  ['process',
#   'future',
#   'offer',
#   'drop',
#   'system',
#   'certain',
#   'realize',
#   'sell',
#   'report',
#   'perform',
#   'idea',
#   'born',
#   'leader',
#   'exactly',
#   'house',
#   'able',
#   'pick',
#   'fund',
#   'wait',
#   'goal',
#   'keep',
#   'national',
#   'future',
#   'million',
#   'peace',
#   'effect',
#   'officer',
#   'civil',
#   'build',
#   'run',
#   'smile',
#   'party',
#   'full',
#   'dream',
#   'across',
#   'particular',
#   'design'],
#  ['long',
#   'animal',
#   'social',
#   'risk',
#   'individual',
#   'girl',
#   'senior',
#   'along',
#   'oil',
#   'behavior',
#   'near',
#   'realize',
#   'region',
#   'lot',
#   'left',
#   'true',
#   'though',
#   'civil',
#   'water',
#   'debate',
#   'national',
#   'together',
#   'news',
#   'meet',
#   'training',
#   'source',
#   'add',
#   'certainly',
#   'yard',
#   'spend',
#   'accept',
#   'five',
#   'bag',
#   'seek',
#   'moment',
#   'task',
#   'couple',
#   'easy',
#   'even',
#   'east',
#   'ability'],
#  ['window',
#   'research',
#   'town',
#   'change',
#   'produce',
#   'although',
#   'reality',
#   'entire',
#   'cost',
#   'along',
#   'girl',
#   'pas',
#   'week',
#   'run',
#   'instead',
#   'everything',
#   'glass',
#   'must',
#   'fly',
#   'sign',
#   'attorney',
#   'speak',
#   'born',
#   'lose',
#   'foreign',
#   'poor',
#   'turn',
#   'student',
#   'alone',
#   'rule',
#   'experience',
#   'dark',
#   'respond',
#   'authority',
#   'special',
#   'visit',
#   'language'],
#  ['notice',
#   'still',
#   'court',
#   'car',
#   'hope',
#   'edge',
#   'alone',
#   'cause',
#   'house',
#   'begin',
#   'candidate',
#   'consumer',
#   'serious',
#   'teach',
#   'else',
#   'skin',
#   'new',
#   'well',
#   'help',
#   'natural',
#   'budget',
#   'south',
#   'rule',
#   'across',
#   'amount',
#   'southern',
#   'official',
#   'fight',
#   'deal',
#   'learn',
#   'whose',
#   'economy'],
#  ['prevent',
#   'outside',
#   'meet',
#   'size',
#   'clear',
#   'point',
#   'billion',
#   'approach',
#   'compare',
#   'agent',
#   'forward',
#   'decide',
#   'establish',
#   'investment',
#   'decision',
#   'area',
#   'language',
#   'boy',
#   'management',
#   'nearly',
#   'include',
#   'fire',
#   'indicate',
#   'sea',
#   'skill',
#   'others',
#   'worry',
#   'three',
#   'many',
#   'light',
#   'feel',
#   'house',
#   'huge',
#   'child',
#   'population',
#   'page',
#   'break'],
#  ['religious',
#   'fall',
#   'natural',
#   'able',
#   'owner',
#   'beautiful',
#   'conference',
#   'short',
#   'tree',
#   'get',
#   'add',
#   'interview',
#   'amount',
#   'opportunity',
#   'consider',
#   'center',
#   'area',
#   'attention',
#   'anything',
#   'join',
#   'type',
#   'suffer',
#   'another',
#   'bad',
#   'share',
#   'reach',
#   'far',
#   'study',
#   'trouble',
#   'animal',
#   'billion',
#   'bank',
#   'nice',
#   'health',
#   'job',
#   'artist',
#   'stock',
#   'black',
#   'particular',
#   'always',
#   'nice',
#   'dinner'],
#  ['prepare',
#   'rather',
#   'grow',
#   'paper',
#   'return',
#   'material',
#   'free',
#   'dark',
#   'investment',
#   'market',
#   'inside',
#   'quickly',
#   'impact',
#   'six',
#   'left',
#   'though',
#   'three',
#   'onto',
#   'within',
#   'exist',
#   'character',
#   'position',
#   'foot',
#   'matter',
#   'every',
#   'team',
#   'parent',
#   'fund',
#   'stuff',
#   'stand',
#   'memory',
#   'ago',
#   'man',
#   'country',
#   'light',
#   'management',
#   'writer',
#   'middle',
#   'environmental',
#   'president'],
#  ['fall',
#   'attorney',
#   'type',
#   'begin',
#   'audience',
#   'leave',
#   'teach',
#   'site',
#   'news',
#   'party',
#   'fact',
#   'sure',
#   'third',
#   'price',
#   'evening',
#   'memory',
#   'paper',
#   'ask',
#   'stand',
#   'try',
#   'attack',
#   'loss',
#   'whatever',
#   'three',
#   'factor',
#   'play',
#   'coach',
#   'onto',
#   'challenge',
#   'country',
#   'tend',
#   'road',
#   'reveal',
#   'local',
#   'put',
#   'probably',
#   'police',
#   'describe',
#   'television',
#   'history',
#   'suddenly',
#   'offer',
#   'four',
#   'term',
#   'fill',
#   'economy',
#   'shoulder',
#   'send',
#   'approach',
#   'section',
#   'work',
#   'instead',
#   'nature',
#   'old',
#   'score',
#   'southern',
#   'possible'],
#  ['prove',
#   'design',
#   'wish',
#   'score',
#   'worry',
#   'hundred',
#   'run',
#   'scientist',
#   'car',
#   'receive',
#   'future',
#   'today',
#   'control',
#   'small',
#   'material',
#   'give',
#   'control',
#   'reality',
#   'collection',
#   'citizen',
#   'think',
#   'usually',
#   'south',
#   'surface',
#   'keep',
#   'human',
#   'house',
#   'travel',
#   'feeling'],
#  ['color',
#   'choice',
#   'determine',
#   'speak',
#   'turn',
#   'support',
#   'usually',
#   'source',
#   'front',
#   'race',
#   'work',
#   'next',
#   'company',
#   'bank',
#   'mother',
#   'reflect',
#   'analysis',
#   'improve',
#   'spend',
#   'everything',
#   'meeting',
#   'goal',
#   'trial',
#   'head',
#   'break',
#   'need',
#   'medium',
#   'create',
#   'defense',
#   'half',
#   'health',
#   'significant',
#   'walk',
#   'cut',
#   'push',
#   'owner',
#   'plan',
#   'along',
#   'across',
#   'exist',
#   'election',
#   'turn',
#   'green',
#   'development',
#   'threat',
#   'others',
#   'including',
#   'place',
#   'enjoy',
#   'change'],
#  ['hit',
#   'minute',
#   'field',
#   'reason',
#   'president',
#   'onto',
#   'marriage',
#   'military',
#   'build',
#   'wide',
#   'travel',
#   'soldier',
#   'foreign',
#   'phone',
#   'employee',
#   'door',
#   'north',
#   'thousand',
#   'series',
#   'response',
#   'seven',
#   'white',
#   'structure',
#   'adult',
#   'want',
#   'power',
#   'war',
#   'medium',
#   'writer',
#   'degree',
#   'stage',
#   'order',
#   'wait',
#   'sit'],
#  ['second',
#   'south',
#   'lawyer',
#   'artist',
#   'figure',
#   'artist',
#   'hotel',
#   'animal',
#   'enter',
#   'always',
#   'perhaps',
#   'oil',
#   'particular',
#   'trouble',
#   'father',
#   'action',
#   'glass',
#   'physical',
#   'change',
#   'compare',
#   'cell',
#   'window',
#   'hard',
#   'see',
#   'admit',
#   'business',
#   'system',
#   'bar',
#   'daughter',
#   'assume',
#   'born',
#   'whether',
#   'place',
#   'true',
#   'appear',
#   'final',
#   'event',
#   'treat',
#   'present',
#   'management',
#   'fear',
#   'close',
#   'approach',
#   'yet',
#   'enter',
#   'notice',
#   'call',
#   'plant'],
#  ['article',
#   'finish',
#   'film',
#   'evening',
#   'budget',
#   'hold',
#   'bar',
#   'true',
#   'paper',
#   'anyone',
#   'painting',
#   'position',
#   'cause',
#   'purpose',
#   'stock',
#   'mind',
#   'challenge',
#   'alone',
#   'traditional',
#   'center',
#   'create',
#   'edge',
#   'different',
#   'exist',
#   'early',
#   'election',
#   'month',
#   'test',
#   'office',
#   'recent',
#   'movie',
#   'today',
#   'cell',
#   'reason',
#   'argue',
#   'pull',
#   'wall',
#   'debate',
#   'road',
#   'charge',
#   'employee',
#   'consider',
#   'phone',
#   'pick',
#   'hundred',
#   'treat',
#   'loss',
#   'finish',
#   'real',
#   'activity',
#   'show',
#   'action',
#   'white',
#   'officer',
#   'wall',
#   'spring',
#   'bit',
#   'exactly'],
#  ['challenge',
#   'skin',
#   'save',
#   'buy',
#   'growth',
#   'town',
#   'positive',
#   'defense',
#   'research',
#   'four',
#   'trial',
#   'series',
#   'measure',
#   'positive',
#   'run',
#   'unit',
#   'worker',
#   'read',
#   'tend',
#   'mr',
#   'sound',
#   'large',
#   'prove',
#   'ok',
#   'remain',
#   'act',
#   'money',
#   'dog',
#   'dream',
#   'matter',
#   'table',
#   'everybody',
#   'nearly',
#   'administration',
#   'activity',
#   'smile',
#   'central',
#   'peace'],
#  ['tend',
#   'claim',
#   'still',
#   'time',
#   'year',
#   'game',
#   'according',
#   'data',
#   'democrat',
#   'decade',
#   'political',
#   'employee',
#   'college',
#   'event',
#   'stay',
#   'detail',
#   'require',
#   'long',
#   'behavior',
#   'congress',
#   'heart',
#   'service',
#   'center',
#   'employee',
#   'south',
#   'one',
#   'despite',
#   'many',
#   'show',
#   'throughout',
#   'line',
#   'everyone',
#   'tough',
#   'ahead',
#   'spring',
#   'sport',
#   'industry',
#   'main',
#   'similar',
#   'design',
#   'industry',
#   'mr',
#   'beautiful',
#   'trouble',
#   'weight',
#   'whether',
#   'establish',
#   'interview',
#   'third',
#   'customer',
#   'republican',
#   'sell']]

# %%
all_topics
# Out:
# [(0,
#   '0.016*"health" + 0.008*"table" + 0.008*"task" + 0.008*"choice" + 0.008*"upon"'),
#  (1,
#   '0.011*"run" + 0.008*"main" + 0.008*"whether" + 0.008*"way" + 0.008*"professional"'),
#  (2,
#   '0.013*"history" + 0.013*"market" + 0.013*"congress" + 0.013*"large" + 0.007*"check"'),
#  (3,
#   '0.010*"million" + 0.010*"building" + 0.010*"point" + 0.010*"single" + 0.010*"big"'),
#  (4,
#   '0.014*"later" + 0.014*"reduce" + 0.009*"space" + 0.009*"cold" + 0.009*"try"'),
#  (0,
#   '0.008*"high" + 0.008*"try" + 0.008*"scientist" + 0.008*"drive" + 0.008*"site"'),
#  (1,
#   '0.008*"item" + 0.008*"capital" + 0.007*"central" + 0.006*"significant" + 0.006*"network"'),
#  (2,
#   '0.007*"tough" + 0.006*"book" + 0.006*"view" + 0.006*"indicate" + 0.005*"think"'),
#  (3,
#   '0.006*"exactly" + 0.006*"present" + 0.006*"anything" + 0.006*"week" + 0.006*"letter"'),
#  (4,
#   '0.007*"language" + 0.007*"ten" + 0.006*"time" + 0.006*"western" + 0.006*"writer"'),
#  (0,
#   '0.009*"kitchen" + 0.009*"within" + 0.009*"heavy" + 0.007*"least" + 0.007*"consider"'),
#  (1,
#   '0.007*"rule" + 0.007*"special" + 0.006*"growth" + 0.006*"mr" + 0.006*"staff"'),
#  (2,
#   '0.006*"turn" + 0.006*"century" + 0.006*"recognize" + 0.006*"relate" + 0.006*"modern"'),
#  (3,
#   '0.008*"detail" + 0.006*"nature" + 0.006*"throughout" + 0.006*"board" + 0.006*"case"'),
#  (4,
#   '0.009*"least" + 0.007*"person" + 0.007*"pull" + 0.007*"seven" + 0.007*"consumer"'),
#  (0,
#   '0.009*"expect" + 0.006*"modern" + 0.006*"tend" + 0.006*"road" + 0.005*"direction"'),
#  (1,
#   '0.007*"yes" + 0.007*"science" + 0.005*"travel" + 0.005*"water" + 0.005*"various"'),
#  (2,
#   '0.008*"high" + 0.007*"floor" + 0.005*"five" + 0.005*"day" + 0.005*"situation"'),
#  (3,
#   '0.007*"tree" + 0.006*"size" + 0.006*"bring" + 0.005*"start" + 0.005*"picture"'),
#  (4,
#   '0.007*"around" + 0.006*"turn" + 0.006*"ever" + 0.006*"smile" + 0.005*"finish"'),
#  (0,
#   '0.006*"grow" + 0.006*"enough" + 0.006*"pas" + 0.006*"control" + 0.005*"least"'),
#  (1,
#   '0.008*"carry" + 0.007*"director" + 0.007*"experience" + 0.005*"north" + 0.005*"brother"'),
#  (2,
#   '0.006*"source" + 0.006*"professor" + 0.006*"address" + 0.006*"congress" + 0.005*"believe"'),
#  (3,
#   '0.006*"benefit" + 0.006*"important" + 0.005*"eye" + 0.005*"lose" + 0.005*"individual"'),
#  (4,
#   '0.006*"seat" + 0.006*"sport" + 0.006*"suggest" + 0.006*"education" + 0.006*"decade"'),
#  (0,
#   '0.009*"painting" + 0.009*"bit" + 0.009*"foot" + 0.009*"international" + 0.009*"free"'),
#  (1,
#   '0.008*"skin" + 0.006*"able" + 0.006*"along" + 0.006*"lose" + 0.006*"national"'),
#  (2,
#   '0.013*"south" + 0.009*"future" + 0.009*"design" + 0.009*"cell" + 0.009*"decade"'),
#  (3,
#   '0.011*"run" + 0.009*"alone" + 0.006*"boy" + 0.006*"house" + 0.006*"window"'),
#  (4,
#   '0.008*"artist" + 0.008*"war" + 0.008*"approach" + 0.008*"enter" + 0.008*"section"')]

# %%
# Extract topic words
topic_words = set()
for topic in all_topics:
    words = topic[1].split(" + ")
    for word in words:
        topic_words.add(word.split("*")[1][1:-1])

# %%
# Get word frequencies over time
word_frequencies = get_word_frequencies(topic_words, all_processed_texts)

# %%
# Evaluate declining themes
declining_themes = []
ratios = [(word, word_frequencies[word] / len(all_processed_texts)) for word in topic_words]
ratios.sort(key=lambda x: x[1], reverse=True)

# %%
ratios
# Out:
# [('high', 0.09),
#  ('mr', 0.08),
#  ('within', 0.07666666666666666),
#  ('south', 0.07333333333333333),
#  ('letter', 0.07333333333333333),
#  ('exactly', 0.07),
#  ('million', 0.07),
#  ('lose', 0.06666666666666667),
#  ('smile', 0.06666666666666667),
#  ('least', 0.06666666666666667),
#  ('table', 0.06333333333333334),
#  ('later', 0.06333333333333334),
#  ('source', 0.06333333333333334),
#  ('consumer', 0.06333333333333334),
#  ('reduce', 0.06333333333333334),
#  ('free', 0.06333333333333334),
#  ('yes', 0.06333333333333334),
#  ('professor', 0.06333333333333334),
#  ('experience', 0.06),
#  ('task', 0.06),
#  ('various', 0.06),
#  ('travel', 0.06),
#  ('run', 0.06),
#  ('central', 0.06),
#  ('day', 0.06),
#  ('grow', 0.06),
#  ('boy', 0.06),
#  ('network', 0.06),
#  ('national', 0.056666666666666664),
#  ('carry', 0.056666666666666664),
#  ('detail', 0.056666666666666664),
#  ('upon', 0.056666666666666664),
#  ('five', 0.056666666666666664),
#  ('able', 0.056666666666666664),
#  ('congress', 0.056666666666666664),
#  ('tend', 0.056666666666666664),
#  ('staff', 0.056666666666666664),
#  ('turn', 0.056666666666666664),
#  ('modern', 0.056666666666666664),
#  ('language', 0.05333333333333334),
#  ('growth', 0.05333333333333334),
#  ('cell', 0.05333333333333334),
#  ('throughout', 0.05333333333333334),
#  ('road', 0.05333333333333334),
#  ('present', 0.05333333333333334),
#  ('start', 0.05333333333333334),
#  ('individual', 0.05333333333333334),
#  ('foot', 0.05333333333333334),
#  ('view', 0.05333333333333334),
#  ('benefit', 0.05333333333333334),
#  ('approach', 0.05333333333333334),
#  ('water', 0.05333333333333334),
#  ('brother', 0.05333333333333334),
#  ('large', 0.05333333333333334),
#  ('tough', 0.05333333333333334),
#  ('rule', 0.05333333333333334),
#  ('skin', 0.05333333333333334),
#  ('house', 0.05333333333333334),
#  ('painting', 0.05333333333333334),
#  ('bit', 0.05),
#  ('scientist', 0.05),
#  ('believe', 0.05),
#  ('floor', 0.05),
#  ('along', 0.05),
#  ('recognize', 0.05),
#  ('alone', 0.05),
#  ('pull', 0.05),
#  ('north', 0.05),
#  ('main', 0.05),
#  ('history', 0.05),
#  ('health', 0.05),
#  ('tree', 0.05),
#  ('future', 0.05),
#  ('control', 0.05),
#  ('person', 0.04666666666666667),
#  ('artist', 0.04666666666666667),
#  ('nature', 0.04666666666666667),
#  ('expect', 0.04666666666666667),
#  ('finish', 0.04666666666666667),
#  ('size', 0.04666666666666667),
#  ('try', 0.04666666666666667),
#  ('board', 0.04666666666666667),
#  ('significant', 0.04666666666666667),
#  ('site', 0.04666666666666667),
#  ('item', 0.04666666666666667),
#  ('way', 0.04666666666666667),
#  ('ever', 0.04666666666666667),
#  ('ten', 0.04666666666666667),
#  ('picture', 0.04666666666666667),
#  ('special', 0.04666666666666667),
#  ('sport', 0.043333333333333335),
#  ('seven', 0.043333333333333335),
#  ('section', 0.043333333333333335),
#  ('whether', 0.043333333333333335),
#  ('cold', 0.043333333333333335),
#  ('heavy', 0.043333333333333335),
#  ('book', 0.043333333333333335),
#  ('market', 0.043333333333333335),
#  ('enter', 0.043333333333333335),
#  ('education', 0.043333333333333335),
#  ('bring', 0.043333333333333335),
#  ('capital', 0.043333333333333335),
#  ('director', 0.04),
#  ('eye', 0.04),
#  ('big', 0.04),
#  ('around', 0.04),
#  ('writer', 0.04),
#  ('enough', 0.04),
#  ('design', 0.04),
#  ('international', 0.04),
#  ('direction', 0.04),
#  ('window', 0.04),
#  ('point', 0.03666666666666667),
#  ('pas', 0.03666666666666667),
#  ('single', 0.03666666666666667),
#  ('think', 0.03666666666666667),
#  ('western', 0.03666666666666667),
#  ('address', 0.03666666666666667),
#  ('time', 0.03666666666666667),
#  ('suggest', 0.03666666666666667),
#  ('space', 0.03666666666666667),
#  ('case', 0.03666666666666667),
#  ('kitchen', 0.03666666666666667),
#  ('week', 0.03666666666666667),
#  ('consider', 0.03666666666666667),
#  ('anything', 0.03666666666666667),
#  ('decade', 0.03333333333333333),
#  ('seat', 0.03333333333333333),
#  ('science', 0.03333333333333333),
#  ('important', 0.03333333333333333),
#  ('choice', 0.03333333333333333),
#  ('professional', 0.03333333333333333),
#  ('check', 0.03333333333333333),
#  ('drive', 0.03),
#  ('indicate', 0.03),
#  ('relate', 0.03),
#  ('building', 0.03),
#  ('century', 0.02666666666666667),
#  ('situation', 0.023333333333333334),
#  ('war', 0.023333333333333334)]

# %%
for word, ratio in ratios:
    if ratio > 0.05:  # Adjust threshold according to the analysis needs
        declining_themes.append(word)

print("Declining themes:", declining_themes)
# Out:
# Declining themes: ['high', 'mr', 'within', 'south', 'letter', 'exactly', 'million', 'lose', 'smile', 'least', 'table', 'later', 'source', 'consumer', 'reduce', 'free', 'yes', 'professor', 'experience', 'task', 'various', 'travel', 'run', 'central', 'day', 'grow', 'boy', 'network', 'national', 'carry', 'detail', 'upon', 'five', 'able', 'congress', 'tend', 'staff', 'turn', 'modern', 'language', 'growth', 'cell', 'throughout', 'road', 'present', 'start', 'individual', 'foot', 'view', 'benefit', 'approach', 'water', 'brother', 'large', 'tough', 'rule', 'skin', 'house', 'painting']

# %% [markdown]
# ### question 4  **What is the sentiment over those themes?

# %%
from textblob import TextBlob

# %%
# Replace with the list of declining themes from question 3
declining_themes = ['high', 'mr', 'within', 'south', 'letter', 'exactly', 'million', 'lose', 'smile']

# %%
data['tokens'][0]
# Out:
# ['Issue conference drop forget reduce affect feel doctor. Owner head hope expert probably either art stuff.',
#  'Director series threat effort technology. Truth manage various long game society.',
#  'Where prepare think control fly. Suddenly must because follow too middle. Must pattern consumer administration which who.',
#  'Ever change though new. Military east why low. Guy dog positive fall my.',
#  'Husband exist thank little break. New career surface blood American. Could couple executive position record experience. Party front phone keep hear material.',
#  'Interview rise on something. Do sea remember mention source car no. Wonder media could college admit phone.',
#  'Commercial pay late point require child. Camera more picture step fight.',
#  'Serious oil much certainly indeed vote security. Total group month offer government. Message near baby skill either can production.',
#  'Imagine onto light culture. Standard particularly cup enter eight second.']

# %%
# Preprocess the text to obtain the tokens for each section
data['tokens'] = data['Section1'] + data['Section1A'] + data['Section7']
data['tokens'] = data['tokens'].apply(lambda x: preprocess(x[0]))

# %%
# Check if a section contains any of the declining themes
data['contains_declining_theme'] = data['tokens'].apply(lambda x: any(theme in x for theme in declining_themes))

# %%
# Compute sentiment polarity and subjectivity for each section using TextBlob
data['sentiment_polarity'] = data['tokens'].apply(lambda x: TextBlob(' '.join(x)).sentiment.polarity)
data['sentiment_subjectivity'] = data['tokens'].apply(lambda x: TextBlob(' '.join(x)).sentiment.subjectivity)

# %%
# Filter the sections that contain declining themes
declining_theme_sections = data[data['contains_declining_theme']]

# %%
# Calculate average sentiment polarity and subjectivity
average_sentiment_polarity = declining_theme_sections['sentiment_polarity'].mean()
average_sentiment_subjectivity = declining_theme_sections['sentiment_subjectivity'].mean()

# %%
print(f'Average sentiment polarity for sections containing declining themes: {average_sentiment_polarity:.2f}')
print(f'Average sentiment subjectivity for sections containing declining themes: {average_sentiment_subjectivity:.2f}')
# Out:
# Average sentiment polarity for sections containing declining themes: 0.12
# Average sentiment subjectivity for sections containing declining themes: 0.44
